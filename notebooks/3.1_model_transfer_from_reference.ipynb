# %% [markdown]
# # Using lifespan models to make predictions on new data ("Transfer")
#
# Created by Saige rutherford adapted by Charlotte Fraza and Johanna Bayer
#
# In this tutorial, we demonstrate how to use large, pretrained normative models to generate predictions for new datasets.  We call this operation a **model transfer**. By transferring, hence applying, the parameters of these models to new data, you can take advantage of the statistical power of large reference cohorts without performing computationally expensive training.

# %% [markdown]
# In this script we will demonstrate how to:
#
# 1. Download and unzip the pretrained normative models
# 2. Load and prepare the transfer datasets (in this example case from OpenNeuro)
# 3. Configure covariates and response variables for the transfer function
# 4. Adapt the model to a new dataset
# 5. Run the transfer prediction using the PCNtoolkit

# %% [markdown]
# First, we install and import the required libraries. These include some libraries to download the pre-trained models, the pcntookit and some libraries to manipulate data in Python.

# %%
# Install the requests library if it's not already installed
try:
    import requests
except ModuleNotFoundError:
    # %pip install requests
# Out:
# Collecting requests
#   Downloading requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.7-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Downloading idna-3.13-py3-none-any.whl.metadata (8.0 kB)
# Collecting urllib3<3,>=1.26 (from requests)
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2023.5.7 (from requests)
#   Downloading certifi-2026.4.22-py3-none-any.whl.metadata (2.5 kB)
# Downloading requests-2.33.1-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.7-cp312-cp312-win_amd64.whl (159 kB)
# Downloading idna-3.13-py3-none-any.whl (68 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading certifi-2026.4.22-py3-none-any.whl (135 kB)
# Installing collected packages: urllib3, idna, charset_normalizer, certifi, requests
#
#    -------- ------------------------------- 1/5 [idna]
#    ---------------- ----------------------- 2/5 [charset_normalizer]
#    ---------------------------------------- 5/5 [requests]
#
# Successfully installed certifi-2026.4.22 charset_normalizer-3.4.7 idna-3.13 requests-2.33.1 urllib3-2.6.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import requests
import xml.etree.ElementTree as ET
from urllib.parse import unquote
import os
import zipfile
import pcntoolkit as ptk
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Download and unzip the pretrained normative models
#
# In the next step, need to get the models into your computing environment. We are going to download all the models from surfdrive: https://surfdrive.surf.nl/s/Mb6mZyFmJeCaPcZ?dir=/zip and store them in a new folder that we create in your local environment.
#
# We first read out the names of all model folders in the remote directory:

# %%
# Define the working directory where all ZIP files will be downloaded
wdir = os.path.abspath("../braincharts/data/")
os.makedirs(wdir, exist_ok=True)

# Define the WebDAV URL and authentication credentials for Surfdrive
BASE_URL = "https://surfdrive.surf.nl/public.php/webdav/zip/"
SHARE_TOKEN = "Mb6mZyFmJeCaPcZ"
PASSWORD = ""

# Send a PROPFIND request to list the contents of the remote directory
headers = {"Depth": "1"}
r = requests.request("PROPFIND", BASE_URL, auth=(SHARE_TOKEN, PASSWORD), headers=headers)

# Parse the XML response returned by the WebDAV server
tree = ET.fromstring(r.content)

# Extract the names of all ZIP files in the remote directory
zip_files = []
for elem in tree.iter():
    if elem.tag.endswith("href"):
        name = unquote(elem.text.split("/")[-1])
        if name.lower().endswith(".zip"):
            zip_files.append(name)

# %% [markdown]
# Then we iterate over the model folder names and download each of them onto your local machine. Execution of this step may take long to run due to the large size (GBs) of the HBR models.

# %%
# Download each ZIP file and save it locally
for fname in zip_files:
    url = BASE_URL + fname
    resp = requests.get(url, auth=(SHARE_TOKEN, PASSWORD), stream=True)

    # Skip files that could not be downloaded successfully
    if resp.status_code != 200:
        continue

    out_path = os.path.join(wdir, fname)
    with open(out_path, "wb") as f:
        for chunk in resp.iter_content(chunk_size=8192):
            if chunk:
                f.write(chunk)

# %% [markdown]
# You can now inspect the zipped model files. Your folder should look something like this:

# %% [markdown]
# `BLRw_ct_DES_lifespan_67K_89sites.zip` <br>
# `HBR_Sb_ct_DES_lifespan_79K_100sites.zip` <br>
# `BLRw_fa_JHU_lifespan_24K_19sites.zip` <br>
# `HBR_Sb_ct_DK_lifespan_79K_100sites.zip` <br>
# `BLRw_sc_lifespan_67K_89sites.zip` <br>
# `HBR_Sb_sc_lifespan_79K_100sites.zip`

# %% [markdown]
# Let’s break down what these filenames mean:
# - BLRw: Bayesian Linear Regression model (Fraza et al.)
# - HBR_Sb: Hierarchical Bayesian Regression model using a SHASH likelihood (de Boer et al., 2024)
# - ct: cortical thickness
# - fa: fractional anisotropy
# - sc: subcortical measures
# - DES: Destrieux atlas parcellation
# - DK: Desikan–Killiany atlas parcellation
# - 67K / 79K / 24K: number of subjects used to train the model
# - 89sites / 100sites / 19sites: number of sites in the training dataset

# %% [markdown]
# We now define paths to the top (parent) directory and the directory that the models will be extracted into:

# %%
# Define the top-level project directory and the data directory (already set as wdir above)
top_dir = os.path.dirname(wdir)  # braincharts/
data_dir = wdir                  # braincharts/data/

# %% [markdown]
# Then we extract the models:

# %%
# Define paths to the zipped model file and the directory where it will be extracted
zip_path = os.path.join(data_dir, "BLRw_sc_lifespan_67K_89sites.zip")
model_dir = os.path.join(data_dir, "BLRw_sc_lifespan_67K_89sites")

# Unzip the pretrained model if it has not already been extracted
if not os.path.exists(model_dir):
    os.makedirs(model_dir, exist_ok=True)
    with zipfile.ZipFile(zip_path, "r") as z:
        z.extractall(model_dir)

# %% [markdown]
# ### 2. Load and prepare the transfer datasets (in this example case from OpenNeuro)
#
# This section focuses on preparing the new data for which we want to generate predictions.
#
# In general, the data should be split into two folds:
# - The adaptation dataset (_ad_), which is used to estimate site differences between the new data and the pretrained models. This dataset is used only for adaptation and is not included in the final analysis.
# - The test dataset (_te_), for which predictions will be generated.
#
# Predictions are made only for the test set.
#
# For this example, we use a publicly available dataset from OpenNeuro. We clone the dataset into a directory called transfer_data. The dataset has already been split into an adaptation set and a test set.
#
# If you plan to use your own data, this is the section you will most likely need to adapt. Your data needs to be split into two folds in a stratified manner, such that the distributions of relevant covariates (e.g., age, sex, site) are represented in both folds. You can use an in-built function for that, or you can create your own custom split. You will also have to make sure that the sex encoding corresponds with the pretrained models (F/M in the BLR case, 0/1 in the HBR SHASH case, with 0 representing female.)

# %%
# Clone the adaptation data into the data directory (skip if already present)
transfer_data_dir = os.path.join(data_dir, "transfer_data")
if not os.path.exists(transfer_data_dir):
    ! git clone https://github.com/predictive-clinical-neuroscience/braincharts.git {transfer_data_dir}

# Define paths to the adaptation and test datasets (in this example derived from OpenNeuro), or to your own data.
data_ad_path = os.path.join(transfer_data_dir, "docs", "OpenNeuroTransfer_ct_ad.csv")
data_te_path = os.path.join(transfer_data_dir, "docs", "OpenNeuroTransfer_ct_te.csv")

# Load the adaptation and test datasets into pandas dataframes
df_ad = pd.read_csv(data_ad_path, index_col=0)
df_te = pd.read_csv(data_te_path, index_col=0)
# Out:
# Cloning into '../braincharts\data\transfer_data'...

# %%
# Create an output directory for transfer predictions
out_dir = model_dir + "_txfr"
os.makedirs(out_dir, exist_ok=True)

# %% [markdown]
# ### 3. Configure covariates and response variables for the transfer function

# %%
# Load the pretrained normative model
model = ptk.NormativeModel.load(model_dir)

# Extract model configuration: batch effects (e.g. site, sex), covariates (e.g. age),
# and response variables (brain measures predicted by the model)
batch_effects = list(model.unique_batch_effects.keys())
covariates = model.covariates
response_vars = model.response_vars
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Load the pretrained normative model
# ----> 2 model = ptk.NormativeModel.load(model_dir)
#       3
#       4 # Extract model configuration: batch effects (e.g. site, sex), covariates (e.g. age),
#       5 # and response variables (brain measures predicted by the model)
#
# File c:\Users\kontsi\AppData\Local\anaconda3\envs\ptk-pu25\Lib\site-packages\pcntoolkit\normative_model.py:464, in NormativeModel.load(cls, path, into)
#     462 assert os.path.exists(path), f"Path {path} does not exist"
#     463 model_path = os.path.join(path, "model", "normative_model.json")
# --> 464 with open(model_path, mode="r", encoding="utf-8") as f:
#     465     metadata = json.load(f)
#     467 savemodel = metadata["savemodel"]
#
# FileNotFoundError: [Errno 2] No such file or directory: '../braincharts\\data\\BLRw_sc_lifespan_67K_89sites\\model\\normative_model.json'

# %%
# Combine adaptation and test data into a single dataframe. You don't need to do that necessarily, but we do it here, because it makes making 
# changes to the variables more easy
df = pd.concat([df_ad, df_te], axis=0)

# Recode sex variable to match the format expected by the model (F/M instead of 0/1)
df["sex"] = df["sex"].map({0: "F", 1: "M"})

# Create a subject ID column from the dataframe index
df["sub_id"] = df.index.astype(str)

# Keep only those response variables that are present in the dataframe
# (prevents errors when the model expects variables that are not in the CSV files)
response_vars = [v for v in response_vars if v in df.columns]

# %% [markdown]
# ### 4 Adapt the model to a new dataset

# %%
# Path to the cached NormData file
norm_data_path = os.path.join(out_dir, "norm_data_pu25_thickness_txfr.nc")

if os.path.exists(norm_data_path):
    # Load the previously saved NormData object — no need to re-run data preparation
    norm_data = ptk.NormData.from_netcdf("pu25_thickness_txfr", norm_data_path)
    print(f"Loaded NormData from {norm_data_path}")
else:
    # Create a NormData object to prepare the data for normative modelling
    norm_data = ptk.NormData.from_dataframe(
        name="pu25_thickness_txfr",
        dataframe=df,
        batch_effects=batch_effects,
        subject_ids="sub_id",
        response_vars=response_vars,
        covariates=covariates,
        remove_Nan=True,
        remove_outliers=True,
        z_threshold=10
    )
    # Save to disk so future runs can skip data preparation
    norm_data.to_netcdf(norm_data_path)
    print(f"Saved NormData to {norm_data_path}")

## In case you want to use your own train-test split instead of an automatically generated one, use these lines instead
#train = ptk.NormData.from_dataframe(name="ad", dataframe=df_ad, covariates=covariates, batch_effects=batch_effects, response_vars=response_vars,
# remove_Nan=True,remove_outliers=True,z_threshold=10)
#test = ptk.NormData.from_dataframe(name="te", dataframe=df_te, covariates=covariates, batch_effects=batch_effects, response_vars=response_vars,
# remove_Nan=True,remove_outliers=True,z_threshold=10))

# Split the data into adaptation (train) and test sets
train, test = norm_data.train_test_split(splits=[0.5, 0.5])
# Out:
# Process: 1226572 - 2026-02-04 19:35:10 - Removed 0 NANs
# Process: 1226572 - 2026-02-04 19:35:10 - Removed 1 outliers for CSF
# Process: 1226572 - 2026-02-04 19:35:10 - Removed 1 outliers for Right-Inf-Lat-Vent
# Process: 1226572 - 2026-02-04 19:35:10 - Removed 1 outliers for WM-hypointensities
# Process: 1226572 - 2026-02-04 19:35:10 - Removed 3 outliers
# Process: 1226572 - 2026-02-04 19:35:10 - Dataset "pu25_thickness_txfr" created.
#     - 543 observations
#     - 515 unique subjects
#     - 1 covariates
#     - 31 response variables
#     - 2 batch effects:
#     	site (6)
# 	sex (2)

# %% [markdown]
# ### 5. Run the transfer prediction using the PCNtoolkit

# %%
# Run transfer prediction to adapt the pretrained model and compute deviation scores
transferred_model = model.transfer_predict(train, test, save_dir=out_dir)
# Out:
# Process: 1226572 - 2026-02-04 19:35:17 - Transferring models on 31 response variables.
# Process: 1226572 - 2026-02-04 19:35:17 - Transferring model for Left-Putamen.
# Process: 1226572 - 2026-02-04 19:35:18 - Transferring model for Left-Pallidum.
# Process: 1226572 - 2026-02-04 19:35:18 - Transferring model for Left-Accumbens-area.
# Process: 1226572 - 2026-02-04 19:35:18 - Transferring model for Right-Accumbens-area.
# Process: 1226572 - 2026-02-04 19:35:18 - Transferring model for SubCortGrayVol.
# Process: 1226572 - 2026-02-04 19:35:18 - Transferring model for Right-Inf-Lat-Vent.
# Process: 1226572 - 2026-02-04 19:35:18 - Transferring model for Right-VentralDC.
# Process: 1226572 - 2026-02-04 19:35:18 - Transferring model for Left-Inf-Lat-Vent.
# Process: 1226572 - 2026-02-04 19:35:18 - Transferring model for 4th-Ventricle.
# Process: 1226572 - 2026-02-04 19:35:18 - Transferring model for Left-Hippocampus.
# Process: 1226572 - 2026-02-04 19:35:18 - Transferring model for Right-Cerebellum-White-Matter.
# Process: 1226572 - 2026-02-04 19:35:18 - Transferring model for Left-Lateral-Ventricle.
# Process: 1226572 - 2026-02-04 19:35:18 - Transferring model for Right-Hippocampus.
# Process: 1226572 - 2026-02-04 19:35:18 - Transferring model for Right-Lateral-Ventricle.
# Process: 1226572 - 2026-02-04 19:35:18 - Transferring model for Right-Caudate.
# Process: 1226572 - 2026-02-04 19:35:18 - Transferring model for Right-Thalamus-Proper.
# Process: 1226572 - 2026-02-04 19:35:18 - Transferring model for 3rd-Ventricle.
# Process: 1226572 - 2026-02-04 19:35:19 - Transferring model for Right-Cerebellum-Cortex.
# Process: 1226572 - 2026-02-04 19:35:19 - Transferring model for Left-Thalamus-Proper.
# Process: 1226572 - 2026-02-04 19:35:19 - Transferring model for Brain-Stem.
# Process: 1226572 - 2026-02-04 19:35:19 - Transferring model for Left-Cerebellum-White-Matter.
# Process: 1226572 - 2026-02-04 19:35:19 - Transferring model for Right-Amygdala.
# Process: 1226572 - 2026-02-04 19:35:19 - Transferring model for Left-VentralDC.
# Process: 1226572 - 2026-02-04 19:35:19 - Transferring model for Left-Caudate.
# Process: 1226572 - 2026-02-04 19:35:19 - Transferring model for WM-hypointensities.
# Process: 1226572 - 2026-02-04 19:35:19 - Transferring model for SupraTentorialVol.
# Process: 1226572 - 2026-02-04 19:35:19 - Transferring model for Right-Pallidum.
# Process: 1226572 - 2026-02-04 19:35:19 - Transferring model for CSF.
# Process: 1226572 - 2026-02-04 19:35:19 - Transferring model for Left-Amygdala.
# Process: 1226572 - 2026-02-04 19:35:19 - Transferring model for Right-Putamen.
# Process: 1226572 - 2026-02-04 19:35:19 - Transferring model for Left-Cerebellum-Cortex.
# Process: 1226572 - 2026-02-04 19:35:19 - Making predictions on 31 response variables.
# Process: 1226572 - 2026-02-04 19:35:19 - Computing z-scores for 31 response variables.
# Process: 1226572 - 2026-02-04 19:35:19 - Computing z-scores for Left-Putamen.
# Process: 1226572 - 2026-02-04 19:35:19 - Computing z-scores for Left-Pallidum.
# Process: 1226572 - 2026-02-04 19:35:19 - Computing z-scores for Left-Accumbens-area.
# Process: 1226572 - 2026-02-04 19:35:19 - Computing z-scores for Right-Accumbens-area.
# Process: 1226572 - 2026-02-04 19:35:19 - Computing z-scores for SubCortGrayVol.
# Process: 1226572 - 2026-02-04 19:35:19 - Computing z-scores for Right-Inf-Lat-Vent.
# Process: 1226572 - 2026-02-04 19:35:19 - Computing z-scores for Right-VentralDC.
# Process: 1226572 - 2026-02-04 19:35:19 - Computing z-scores for Left-Inf-Lat-Vent.
# Process: 1226572 - 2026-02-04 19:35:19 - Computing z-scores for 4th-Ventricle.
# Process: 1226572 - 2026-02-04 19:35:20 - Computing z-scores for Left-Hippocampus.
# Process: 1226572 - 2026-02-04 19:35:20 - Computing z-scores for Right-Cerebellum-White-Matter.
# Process: 1226572 - 2026-02-04 19:35:20 - Computing z-scores for Left-Lateral-Ventricle.
# Process: 1226572 - 2026-02-04 19:35:20 - Computing z-scores for Right-Hippocampus.
# Process: 1226572 - 2026-02-04 19:35:20 - Computing z-scores for Right-Lateral-Ventricle.
# Process: 1226572 - 2026-02-04 19:35:20 - Computing z-scores for Right-Caudate.
# Process: 1226572 - 2026-02-04 19:35:20 - Computing z-scores for Right-Thalamus-Proper.
# Process: 1226572 - 2026-02-04 19:35:20 - Computing z-scores for 3rd-Ventricle.
# Process: 1226572 - 2026-02-04 19:35:20 - Computing z-scores for Right-Cerebellum-Cortex.
# Process: 1226572 - 2026-02-04 19:35:20 - Computing z-scores for Left-Thalamus-Proper.
# Process: 1226572 - 2026-02-04 19:35:20 - Computing z-scores for Brain-Stem.
# Process: 1226572 - 2026-02-04 19:35:20 - Computing z-scores for Left-Cerebellum-White-Matter.
# Process: 1226572 - 2026-02-04 19:35:20 - Computing z-scores for Right-Amygdala.
# Process: 1226572 - 2026-02-04 19:35:20 - Computing z-scores for Left-VentralDC.
# Process: 1226572 - 2026-02-04 19:35:20 - Computing z-scores for Left-Caudate.
# Process: 1226572 - 2026-02-04 19:35:20 - Computing z-scores for WM-hypointensities.
# Process: 1226572 - 2026-02-04 19:35:20 - Computing z-scores for SupraTentorialVol.
# Process: 1226572 - 2026-02-04 19:35:20 - Computing z-scores for Right-Pallidum.
# Process: 1226572 - 2026-02-04 19:35:20 - Computing z-scores for CSF.
# Process: 1226572 - 2026-02-04 19:35:20 - Computing z-scores for Left-Amygdala.
# Process: 1226572 - 2026-02-04 19:35:20 - Computing z-scores for Right-Putamen.
# Process: 1226572 - 2026-02-04 19:35:20 - Computing z-scores for Left-Cerebellum-Cortex.
# Process: 1226572 - 2026-02-04 19:35:20 - Computing centiles for 31 response variables.
# Process: 1226572 - 2026-02-04 19:35:20 - Computing centiles for Left-Putamen.
# Process: 1226572 - 2026-02-04 19:35:21 - Computing centiles for Left-Pallidum.
# Process: 1226572 - 2026-02-04 19:35:21 - Computing centiles for Left-Accumbens-area.
# Process: 1226572 - 2026-02-04 19:35:21 - Computing centiles for Right-Accumbens-area.
# Process: 1226572 - 2026-02-04 19:35:21 - Computing centiles for SubCortGrayVol.
# Process: 1226572 - 2026-02-04 19:35:21 - Computing centiles for Right-Inf-Lat-Vent.
# Process: 1226572 - 2026-02-04 19:35:22 - Computing centiles for Right-VentralDC.
# Process: 1226572 - 2026-02-04 19:35:22 - Computing centiles for Left-Inf-Lat-Vent.
# Process: 1226572 - 2026-02-04 19:35:22 - Computing centiles for 4th-Ventricle.
# Process: 1226572 - 2026-02-04 19:35:22 - Computing centiles for Left-Hippocampus.
# Process: 1226572 - 2026-02-04 19:35:22 - Computing centiles for Right-Cerebellum-White-Matter.
# Process: 1226572 - 2026-02-04 19:35:23 - Computing centiles for Left-Lateral-Ventricle.
# Process: 1226572 - 2026-02-04 19:35:23 - Computing centiles for Right-Hippocampus.
# Process: 1226572 - 2026-02-04 19:35:23 - Computing centiles for Right-Lateral-Ventricle.
# Process: 1226572 - 2026-02-04 19:35:23 - Computing centiles for Right-Caudate.
# Process: 1226572 - 2026-02-04 19:35:23 - Computing centiles for Right-Thalamus-Proper.
# Process: 1226572 - 2026-02-04 19:35:23 - Computing centiles for 3rd-Ventricle.
# Process: 1226572 - 2026-02-04 19:35:24 - Computing centiles for Right-Cerebellum-Cortex.
# Process: 1226572 - 2026-02-04 19:35:24 - Computing centiles for Left-Thalamus-Proper.
# Process: 1226572 - 2026-02-04 19:35:24 - Computing centiles for Brain-Stem.
# Process: 1226572 - 2026-02-04 19:35:24 - Computing centiles for Left-Cerebellum-White-Matter.
# Process: 1226572 - 2026-02-04 19:35:24 - Computing centiles for Right-Amygdala.
# Process: 1226572 - 2026-02-04 19:35:25 - Computing centiles for Left-VentralDC.
# Process: 1226572 - 2026-02-04 19:35:25 - Computing centiles for Left-Caudate.
# Process: 1226572 - 2026-02-04 19:35:25 - Computing centiles for WM-hypointensities.
# Process: 1226572 - 2026-02-04 19:35:25 - Computing centiles for SupraTentorialVol.
# Process: 1226572 - 2026-02-04 19:35:25 - Computing centiles for Right-Pallidum.
# Process: 1226572 - 2026-02-04 19:35:25 - Computing centiles for CSF.
# Process: 1226572 - 2026-02-04 19:35:25 - Computing centiles for Left-Amygdala.
# Process: 1226572 - 2026-02-04 19:35:25 - Computing centiles for Right-Putamen.
# Process: 1226572 - 2026-02-04 19:35:26 - Computing centiles for Left-Cerebellum-Cortex.
# Process: 1226572 - 2026-02-04 19:35:26 - Computing log-probabilities for 31 response variables.
# Process: 1226572 - 2026-02-04 19:35:26 - Computing log-probabilities for Left-Putamen.
# Process: 1226572 - 2026-02-04 19:35:26 - Computing log-probabilities for Left-Pallidum.
# Process: 1226572 - 2026-02-04 19:35:26 - Computing log-probabilities for Left-Accumbens-area.
# Process: 1226572 - 2026-02-04 19:35:26 - Computing log-probabilities for Right-Accumbens-area.
# Process: 1226572 - 2026-02-04 19:35:26 - Computing log-probabilities for SubCortGrayVol.
# Process: 1226572 - 2026-02-04 19:35:26 - Computing log-probabilities for Right-Inf-Lat-Vent.
# Process: 1226572 - 2026-02-04 19:35:26 - Computing log-probabilities for Right-VentralDC.
# Process: 1226572 - 2026-02-04 19:35:26 - Computing log-probabilities for Left-Inf-Lat-Vent.
# Process: 1226572 - 2026-02-04 19:35:26 - Computing log-probabilities for 4th-Ventricle.
# Process: 1226572 - 2026-02-04 19:35:26 - Computing log-probabilities for Left-Hippocampus.
# Process: 1226572 - 2026-02-04 19:35:26 - Computing log-probabilities for Right-Cerebellum-White-Matter.
# Process: 1226572 - 2026-02-04 19:35:26 - Computing log-probabilities for Left-Lateral-Ventricle.
# Process: 1226572 - 2026-02-04 19:35:26 - Computing log-probabilities for Right-Hippocampus.
# Process: 1226572 - 2026-02-04 19:35:26 - Computing log-probabilities for Right-Lateral-Ventricle.
# Process: 1226572 - 2026-02-04 19:35:26 - Computing log-probabilities for Right-Caudate.
# Process: 1226572 - 2026-02-04 19:35:26 - Computing log-probabilities for Right-Thalamus-Proper.
# Process: 1226572 - 2026-02-04 19:35:26 - Computing log-probabilities for 3rd-Ventricle.
# Process: 1226572 - 2026-02-04 19:35:26 - Computing log-probabilities for Right-Cerebellum-Cortex.
# Process: 1226572 - 2026-02-04 19:35:26 - Computing log-probabilities for Left-Thalamus-Proper.
# Process: 1226572 - 2026-02-04 19:35:26 - Computing log-probabilities for Brain-Stem.
# Process: 1226572 - 2026-02-04 19:35:26 - Computing log-probabilities for Left-Cerebellum-White-Matter.
# Process: 1226572 - 2026-02-04 19:35:27 - Computing log-probabilities for Right-Amygdala.
# Process: 1226572 - 2026-02-04 19:35:27 - Computing log-probabilities for Left-VentralDC.
# Process: 1226572 - 2026-02-04 19:35:27 - Computing log-probabilities for Left-Caudate.
# Process: 1226572 - 2026-02-04 19:35:27 - Computing log-probabilities for WM-hypointensities.
# Process: 1226572 - 2026-02-04 19:35:27 - Computing log-probabilities for SupraTentorialVol.
# Process: 1226572 - 2026-02-04 19:35:27 - Computing log-probabilities for Right-Pallidum.
# Process: 1226572 - 2026-02-04 19:35:27 - Computing log-probabilities for CSF.
# Process: 1226572 - 2026-02-04 19:35:27 - Computing log-probabilities for Left-Amygdala.
# Process: 1226572 - 2026-02-04 19:35:27 - Computing log-probabilities for Right-Putamen.
# Process: 1226572 - 2026-02-04 19:35:27 - Computing log-probabilities for Left-Cerebellum-Cortex.
# Process: 1226572 - 2026-02-04 19:35:27 - Computing yhat for 31 response variables.
# Process: 1226572 - 2026-02-04 19:35:27 - Computing yhat for Left-Putamen.
# Process: 1226572 - 2026-02-04 19:35:31 - Computing yhat for Left-Pallidum.
# Process: 1226572 - 2026-02-04 19:35:35 - Computing yhat for Left-Accumbens-area.
# Process: 1226572 - 2026-02-04 19:35:39 - Computing yhat for Right-Accumbens-area.
# Process: 1226572 - 2026-02-04 19:35:43 - Computing yhat for SubCortGrayVol.
# Process: 1226572 - 2026-02-04 19:35:47 - Computing yhat for Right-Inf-Lat-Vent.
# Process: 1226572 - 2026-02-04 19:35:51 - Computing yhat for Right-VentralDC.
# Process: 1226572 - 2026-02-04 19:35:56 - Computing yhat for Left-Inf-Lat-Vent.
# Process: 1226572 - 2026-02-04 19:36:00 - Computing yhat for 4th-Ventricle.
# Process: 1226572 - 2026-02-04 19:36:04 - Computing yhat for Left-Hippocampus.
# Process: 1226572 - 2026-02-04 19:36:08 - Computing yhat for Right-Cerebellum-White-Matter.
# Process: 1226572 - 2026-02-04 19:36:12 - Computing yhat for Left-Lateral-Ventricle.
# Process: 1226572 - 2026-02-04 19:36:16 - Computing yhat for Right-Hippocampus.
# Process: 1226572 - 2026-02-04 19:36:21 - Computing yhat for Right-Lateral-Ventricle.
# Process: 1226572 - 2026-02-04 19:36:26 - Computing yhat for Right-Caudate.
# Process: 1226572 - 2026-02-04 19:36:30 - Computing yhat for Right-Thalamus-Proper.
# Process: 1226572 - 2026-02-04 19:36:34 - Computing yhat for 3rd-Ventricle.
# Process: 1226572 - 2026-02-04 19:36:38 - Computing yhat for Right-Cerebellum-Cortex.
# Process: 1226572 - 2026-02-04 19:36:42 - Computing yhat for Left-Thalamus-Proper.
# Process: 1226572 - 2026-02-04 19:36:46 - Computing yhat for Brain-Stem.
# Process: 1226572 - 2026-02-04 19:36:50 - Computing yhat for Left-Cerebellum-White-Matter.
# Process: 1226572 - 2026-02-04 19:36:54 - Computing yhat for Right-Amygdala.
# Process: 1226572 - 2026-02-04 19:36:57 - Computing yhat for Left-VentralDC.
# Process: 1226572 - 2026-02-04 19:37:01 - Computing yhat for Left-Caudate.
# Process: 1226572 - 2026-02-04 19:37:04 - Computing yhat for WM-hypointensities.
# Process: 1226572 - 2026-02-04 19:37:07 - Computing yhat for SupraTentorialVol.
# Process: 1226572 - 2026-02-04 19:37:11 - Computing yhat for Right-Pallidum.
