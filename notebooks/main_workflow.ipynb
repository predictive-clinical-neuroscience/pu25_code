# %% [markdown]
# # 1. Main Workflow
#
# This notebook describes the main workflow of normative modelling (NM). It contains the accompanying code for the manuscript: ___, but can also be used as a standalone learning tool for NM.
#
# ## 1.0 Setting up the environment
#
# -----
#
# <details>
# <summary><b>System requirements</b></summary>
#
# To follow this guide, you will need:
# - Either a Mac, Linux, or Windows machine with WSL (Windows Subsystem for Linux) installed.
# - About ___ GB of free disk space (for the data and the environment)
# - About ___ GB of RAM (more is better, but not required)
# - A decent processor (we recommend a multi-core CPU)
# - A working internet connection (for installing the packages and downloading the data)
#
# For Windows users with WSL, everything that follows will be done in the WSL terminal. You will have to follow the installation instructions for Linux/Mac.
#
# </details>
#
# -----
#
# <details>
# <summary><b>Setting up Anaconda</b></summary>
#
# Anaconda is a free and open-source distribution of the Python and R programming languages for scientific computing, that aims to simplify package management and deployment. We highly recommend using Anaconda (or an alternative like miniconda or venv) to manage your python environment. We will use Anaconda in this tutorial.
#
# Follow the instructions on the anaconda website: https://www.anaconda.com/docs/getting-started/anaconda/install
#
# Verify the installation by running the following command in your terminal:
#
# ```bash
# conda --version
# ```
#
# If you see the version number, you are good to go.
#
# </details>
#
# -----
#
# <details>
# <summary><b>Creating an environment and install the PCNtoolkit</b></summary>
#
# Choose an environment name, here we will use `ptk` as a placeholder. We install pcntoolkit version 1.2.0.post1. We advice you to download this specific version as it is the version that this notebook was tested with. We cannot guarranty that older or newer versions of pcntoolkit will work with this notebook.
#
# ```bash
# conda create -n ptk python=3.12
# conda activate ptk
# pip install pcntoolkit==1.2.0.post1
# conda install -c conda-forge jupyter ipykernel ipywidgets
# ```
#
# Now to verify that the installation is successful, run the following code:
#
# ```bash
# python -c "import pcntoolkit as pcn; print(pcn.__version__)"
# ```
#
# This should print `1.2.0.post1` without any errors.
#
# </details>
#
# -----
#
# ## 1.1 Data Selection 🥦
#
# -----
# ### Data inclusion criteria
#
# A large reference - or normative - set is required to train a well-calibrated normative model. There are two types of uncertainty that have to be considered when building a normative model; epistemic and aleatoric uncertainty. The epistemic uncertainty is the uncertainty in our knowledge, while the aleatoric uncertainty is due to the natural variation in the population. The latter is what we aim to capture with our normative models, and to model it as accurately as possible, the former has to be minimized. As the epistemic uncertainty decreases with the size of the training data, it is desired to have a large reference set.
#
# What can be considered a reference set depends on the research question. If the goal is to parse deviations from a healthy population, the reference set should include only healthy participants. If the goal is to parse heterogeneity within a clinical cohort, one could choose to use a set of participants with that particular condition as the reference set. For instance, if one is interested to parse heterogeneity within a clinical cohort of patients with major depressive disorder (MDD), the reference set could include MDD patients who have responded well to medication.
#
# We will use cortical thickness IDP's derived from several different datasets, which we list below. The datasets are all pre-processed, and included in this repo. All the preprocessing was done using [freesurfer](https://surfer.nmr.mgh.harvard.edu/), with the `recon-all` command. We extracted the mean cortical thickness values following the Destrieux parcellation [1].
#
# We use the FCON1000 dataset, which is freely available at the ([FCON1000 website](https://fcon_1000.projects.nitrc.org/indi/fcp_abcd/abcd.html).
# ). In addition, we will use a number of clinical datasets from the openneuro portal:
#
# 1. [ds003568](https://openneuro.org/datasets/ds003568/versions/1.0.4) - Contains data from 49 subjects (31F, 18M), aged between 12 and 19 (mean 15.9, std 1.8). Clinical labels are Healthy Control (HC) (20) and Major Depression Disorder (MDD) (29) [2]
# 2. [ds003653](https://openneuro.org/datasets/ds003653/versions/1.0.0) - Contains data from 73 subjects (56F, 17M), aged between 19 and 44 (mean 29.1, std 6.6). Clinical labels are HC (39) and MDD (33s) [3]
#
# [1] Destrieux, Christophe, et al. "Automatic parcellation of human cortical gyri and sulci using standard anatomical nomenclature." Neuroimage 53.1 (2010): 1-15.
# [2] Lucrezia Liuzzi, Katharine Chang, Charles Zheng, Hanna Keren, Dipta Saha, Dylan Nielson and Argyris Stringaris, Magnetoencephalographic Correlates of Mood and Reward Dynamics in Human Adolescents, Cerebral Cortex 2021
#
# [3] Anna Manelis, Ph.D., David A.A. Baranger, Ph.D., Skye Satz, B.S., Rachel Ragozzino, M.A., Satish Iyengar, Ph.D., Holly A. Swartz, M.D., Yaroslav O. Halchenko, Ph.D. Cortical myelin measured by the T1w/T2w ratio in individuals with depressive disorders and healthy controls.
#
# To cite the associated paper use: Baranger D, Halchenko YO, Satz S, Ragozzino R, Iyengar S, Swartz HA, Manelis A. 2021. Aberrant levels of cortical myelin distinguish individuals with unipolar depression from healthy controls, DOI: 10.1101/2021.02.25.21252472v2

# %%
import pandas as pd

try:
    df = pd.read_csv("../data/fcon1000.csv")
except FileNotFoundError:
    # Load the data from the GH repo if the local file is not present
    df = pd.read_csv(
        "https://raw.githubusercontent.com/predictive-clinical-neuroscience/pu25_code/refs/heads/main/data/fcon1000.csv"
    )
df["sex"] = df.apply(lambda x: {0: "F", 1: "M"}[x["sex"]], axis=1)
print(df['site'].unique())
df.describe()
# Out:
# ['AnnArbor_a' 'AnnArbor_b' 'Atlanta' 'Baltimore' 'Bangor' 'Beijing_Zang'
#  'Berlin_Margulies' 'Cambridge_Buckner' 'Cleveland' 'ICBM' 'Leiden_2180'
#  'Leiden_2200' 'Milwaukee_b' 'Munchen' 'NewYork_a' 'NewYork_a_ADHD'
#  'Newark' 'Oulu' 'Oxford' 'PaloAlto' 'Pittsburgh' 'Queensland'
#  'SaintLouis']
#                age  lh_G_and_S_frontomargin  lh_G_and_S_occipital_inf  \
# count  1078.000000              1078.000000               1078.000000
# mean     28.251224                 2.372937                  2.383840
# std      13.464724                 0.192185                  0.170751
# min       7.880000                 1.653000                  1.889000
# 25%      21.000000                 2.244250                  2.267250
# 50%      22.000000                 2.361500                  2.382000
# 75%      29.000000                 2.486000                  2.498750
# max      85.000000                 3.047000                  3.010000
#
#        lh_G_and_S_paracentral  lh_G_and_S_subcentral  \
# count             1078.000000            1078.000000
# mean                 2.310856               2.698957
# std                  0.190248               0.182866
# min                  1.383000               2.147000
# 25%                  2.184250               2.574000
# 50%                  2.313000               2.691500
# 75%                  2.444000               2.821000
# max                  3.021000               3.438000
#
#        lh_G_and_S_transv_frontopol  lh_G_and_S_cingul-Ant  \
# count                  1078.000000            1078.000000
# mean                      2.610888               2.753899
# std                       0.225693               0.179482
# min                       1.910000               2.151000
# 25%                       2.460000               2.629000
# 50%                       2.608000               2.749500
# 75%                       2.750750               2.865000
# max                       3.432000               3.542000
#
#        lh_G_and_S_cingul-Mid-Ant  lh_G_and_S_cingul-Mid-Post  \
# count                1078.000000                 1078.000000
# mean                    2.697544                    2.632217
# std                     0.179243                    0.158939
# min                     2.158000                    2.028000
# 25%                     2.581000                    2.529000
# 50%                     2.703500                    2.641000
# 75%                     2.818750                    2.739000
# max                     3.330000                    3.143000
#
#        lh_G_cingul-Post-dorsal  ...  rh_S_pericallosal  rh_S_postcentral  \
# count              1078.000000  ...        1078.000000       1078.000000
# mean                  2.959526  ...           1.979635          2.104468
# std                   0.195792  ...           0.281369          0.161474
# min                   2.240000  ...           1.144000          1.635000
# 25%                   2.840250  ...           1.773250          1.997000
# 50%                   2.956000  ...           1.943500          2.100000
# 75%                   3.088500  ...           2.155500          2.218750
# max                   3.608000  ...           3.119000          2.681000
#
#        rh_S_precentral-inf-part  rh_S_precentral-sup-part  rh_S_suborbital  \
# count               1078.000000               1078.000000      1078.000000
# mean                   2.451929                  2.417430         2.497463
# std                    0.160934                  0.182979         0.400458
# min                    1.744000                  1.503000         1.585000
# 25%                    2.354000                  2.307000         2.208250
# 50%                    2.450000                  2.433000         2.437000
# 75%                    2.554000                  2.537750         2.730500
# max                    3.042000                  2.960000         4.066000
#
#        rh_S_subparietal  rh_S_temporal_inf  rh_S_temporal_sup  \
# count       1078.000000        1078.000000        1078.000000
# mean           2.401750           2.474282           2.495482
# std            0.162933           0.207039           0.139035
# min            1.897000           1.583000           1.943000
# 25%            2.291250           2.365000           2.406500
# 50%            2.400000           2.498500           2.499000
# 75%            2.508000           2.607000           2.587000
# max            2.944000           3.111000           2.978000
#
#        rh_S_temporal_transverse  rh_MeanThickness
# count               1078.000000       1078.000000
# mean                   2.554019          2.485162
# std                    0.313909          0.097570
# min                    1.618000          2.056150
# 25%                    2.330000          2.423033
# 50%                    2.538500          2.487950
# 75%                    2.768500          2.547210
# max                    3.581000          2.837260
#
# [8 rows x 151 columns]

# %%
try:
    openneuro_df = pd.read_csv("../data/openneuro_main.csv")
except FileNotFoundError:
    # Load the data from the GH repo if the local file is not present
    openneuro_df = pd.read_csv(
        "https://raw.githubusercontent.com/predictive-clinical-neuroscience/pu25_code/refs/heads/main/data/openneuro_main.csv"
    )
openneuro_df.describe()
# Do this when the new data comes in
# # Make sure all datasets follow the same naming convention
# openneuro_df.loc[openneuro_df["group"] == "HV", "group"] = "HC"
# openneuro_df.loc[openneuro_df["group"] == "UD", "group"] = "MDD"
# openneuro_df.rename(columns={"dataset": "site"}, inplace=True)
# openneuro_df = openneuro_df[openneuro_df['group'].isin(['HC','MDD'])]
# openneuro_df.to_csv("../data/openneuro.csv")
# Out:
#        lh_G_Ins_lg_and_S_cent_ins  lh_G_and_S_cingul-Ant  \
# count                  121.000000             121.000000
# mean                     3.143430               2.690140
# std                      0.244041               0.146431
# min                      2.109000               2.266000
# 25%                      3.013000               2.603000
# 50%                      3.143000               2.671000
# 75%                      3.297000               2.797000
# max                      3.712000               3.131000
#
#        lh_G_and_S_cingul-Mid-Ant  lh_G_and_S_cingul-Mid-Post  \
# count                 121.000000                  121.000000
# mean                    2.655661                    2.592851
# std                     0.134380                    0.117079
# min                     2.377000                    2.289000
# 25%                     2.557000                    2.516000
# 50%                     2.672000                    2.592000
# 75%                     2.746000                    2.675000
# max                     3.005000                    2.986000
#
#        lh_G_and_S_frontomargin  lh_G_and_S_occipital_inf  \
# count               121.000000                121.000000
# mean                  2.394165                  2.523529
# std                   0.161400                  0.195824
# min                   1.904000                  1.904000
# 25%                   2.298000                  2.412000
# 50%                   2.409000                  2.517000
# 75%                   2.492000                  2.620000
# max                   2.741000                  3.068000
#
#        lh_G_and_S_paracentral  lh_G_and_S_subcentral  \
# count              121.000000             121.000000
# mean                 2.503149               2.782430
# std                  0.159701               0.163217
# min                  2.127000               2.306000
# 25%                  2.401000               2.675000
# 50%                  2.508000               2.780000
# 75%                  2.586000               2.916000
# max                  2.942000               3.197000
#
#        lh_G_and_S_transv_frontopol  lh_G_cingul-Post-dorsal  ...  \
# count                   121.000000               121.000000  ...
# mean                      2.640331                 2.867579  ...
# std                       0.192546                 0.130385  ...
# min                       2.161000                 2.562000  ...
# 25%                       2.520000                 2.786000  ...
# 50%                       2.633000                 2.870000  ...
# 75%                       2.757000                 2.963000  ...
# max                       3.214000                 3.147000  ...
#
#        rh_S_pericallosal  rh_S_postcentral  rh_S_precentral-inf-part  \
# count         121.000000        121.000000                121.000000
# mean            1.675826          2.227694                  2.499851
# std             0.147785          0.116028                  0.137852
# min             1.415000          1.949000                  1.932000
# 25%             1.573000          2.135000                  2.412000
# 50%             1.657000          2.222000                  2.513000
# 75%             1.749000          2.313000                  2.590000
# max             2.097000          2.493000                  2.755000
#
#        rh_S_precentral-sup-part  rh_S_suborbital  rh_S_subparietal  \
# count                121.000000       121.000000        121.000000
# mean                   2.445992         2.245934          2.394140
# std                    0.213077         0.300015          0.113591
# min                    1.600000         1.540000          2.110000
# 25%                    2.373000         2.059000          2.322000
# 50%                    2.488000         2.231000          2.384000
# 75%                    2.578000         2.448000          2.474000
# max                    2.798000         3.045000          2.734000
#
#        rh_S_temporal_inf  rh_S_temporal_sup  rh_S_temporal_transverse  \
# count         121.000000         121.000000                121.000000
# mean            2.453570           2.563645                  2.592876
# std             0.134184           0.096870                  0.281580
# min             2.147000           2.339000                  1.945000
# 25%             2.356000           2.500000                  2.426000
# 50%             2.448000           2.570000                  2.594000
# 75%             2.556000           2.627000                  2.765000
# max             2.806000           2.799000                  3.255000
#
#               age
# count  121.000000
# mean    23.766116
# std      8.367791
# min     12.000000
# 25%     17.000000
# 50%     22.300000
# 75%     29.300000
# max     44.300000
#
# [8 rows x 149 columns]

# %% [markdown]
# ----
#
# ### Covariates, batch effects, and response variables
#
# As we will see, the input data generally consist of a number of covariates, a number of batch effect dimensions, and a number of response variables. The covariates are typically continuous variables, like age and height, but can also be numerically encoded categorical variables, like sex. The batch effect dimensions are categorical variables, scan site or scanner brand/model. The response variables are continuous variables, like brain volumes or brain activity patterns. All these variables must be available for all subjects in the reference set.
#
# Normative models made using the PCNtoolkit version 1.1.0 all consist of one or more linear regressions on the covariates, and a mechanism to handle batch effects, which depends on the type of model. Which variables to select as covariates and batch effects depends on the research question, but it is generally best to include variables that are known to be relevant for the research question. It is important to understand that the goal in normative modelling is to get deviation scores that are as independent as possible from the covariates and batch effects. In an example scenario, if we want to study the effect of meditation on , like age, sex, and brain activity patterns, but not include variables that are  like education level or income.
#
# Sufficient care must be taken to ensure that all data sources adhere to the same schema. For instance, if the reference set includes certain clinical variables, like age and height,these should be available and expressed in consistent units in all other data sources. Furthermore, the PCNtoolkit demands that any data for which predictions are to be made, are from batches that were present in the training set. I.e., a model which captures site effects can not make predictions on data from a site which was not present in the training set.
#
# In the following plot, the left side shows the distribution of the site and sex in the FCON1000 dataset. These variables will be included as batch effects in the model. The right side shows the relationship between age and paracentral thickness. This is a relationship that we want to remove from our deviation scores, so we will include age as a covariate in the model, and model paracentral thickness as a response variable. In fact, we will make a normative model for all the IDPs in the dataset, using age as a covariate, and sex and site as batch effects.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2, figsize=(15, 5))
sns.countplot(y="site", data=df, ax=ax[0], hue="sex", palette="Set2", legend=False)
sns.scatterplot(
    x="age",
    y="lh_G_and_S_paracentral",
    data=df,
    ax=ax[1],
    hue="sex",
    palette="Set2",
)
ax[0].set_title("Site and sex distribution")
ax[1].set_title("Age and paracentral thickness")
plt.show()
df.shape
# Out:
# (1078, 154)

# %% [markdown]
# So the lists of covariates, batch effects, and response variables are:

# %%
import copy
subject_id = "sub_id"
covariates = ["age"]
batch_effects = ["site", "sex"]
non_respvars = [subject_id] + covariates + batch_effects

# Only keep variable that are not covariates, batch effects, or subject id
response_variables = filter(lambda x: x not in non_respvars, df.columns)
# Only keep variables with variance
response_variables = filter(lambda x: df[x].var() > 0, response_variables)
# Only keep variables that are not categorical
response_variables = filter(lambda x: df[x].dtype != "object", response_variables)
response_variables = list(response_variables)[:5]
print(response_variables)
# Out:
# ['lh_G_and_S_frontomargin', 'lh_G_and_S_occipital_inf', 'lh_G_and_S_paracentral', 'lh_G_and_S_subcentral', 'lh_G_and_S_transv_frontopol']

# %% [markdown]
# ## 1.2 Data preparation 🔪
#
# Preparing the data for modelling consists of a few steps:
# - dealing with missing values
# - outlier removal
# - combining different data sources
# - train-test split
# - standardization
#
# All these steps are implemented in the PCNtoolkit, the first three are provided by the `NormData` class, which we will use in the next code block.
#
# For missingness and outliers, the PCNtoolkit will automatically remove the affected subjects in a row-wise manner. If another strategy is desired, the user can preprocess the data manually before passing it to the PCNtoolkit.
#
# For the train-test split, the PCNtoolkit will split the data into a train and test set using the `train_test_split` function from scikit-learn, and a stratification on batch effects is automatically carried out. Here, too, the user can choose to use another strategy and load the split data manually into the PCNtoolkit.
#
# For standardization, the PCNtoolkit will store the standardization coefficients in the model object, so that the same scaling is applied to any new data that is used to make predictions.
#
# -----
#
# ### Dealing with missing values and outliers
#
# The PCNtoolkit uses the `NormData` class as a data container. Any data that is loaded into this class will be automatically checked for missing values and outliers, unless the user specifies otherwise. Affected subjects will be removed from the dataset.
#
# Our model dataset has no missing values, so we will manually set some values to NaN for demonstration purposes.

# %%
from pcntoolkit import NormData
import numpy as np

# Set some random values to NaN
df.iloc[2, 3] = None
df.iloc[5, 7] = np.nan

reference_norm_data = NormData.from_dataframe(
    name="fcon1000",
    dataframe=df,
    covariates=covariates,
    batch_effects=batch_effects,
    response_vars=response_variables,
    subject_ids=subject_id,
    remove_Nan=True,
    remove_outliers=True,
    z_threshold=10,  # The default here is 3, but we use 10 for demonstration purposes
)
# Out:
# Process: 60478 - 2026-05-05 14:45:48 - Removed 2 NANs
# Process: 60478 - 2026-05-05 14:45:48 - Removed 0 outliers
# Process: 60478 - 2026-05-05 14:45:48 - Dataset "fcon1000" created.
#     - 1076 observations
#     - 1076 unique subjects
#     - 1 covariates
#     - 5 response variables
#     - 2 batch effects:
#     	site (23)
# 	sex (2)

# %% [markdown]
# ------
#
# ### Combining different data sources
#
# In many cases, our data comes from different sources. Here, we work with the FCON1000 dataset and the datasets downloaded from Openneuro. The first one is already loaded as the reference dataset above, now we will load the other data in NormData objects. We will then merge the healthy controls with the reference set, and keep the rest separate for later analysis.

# %%
# Split into healthy and patient groups
healthy_idx = openneuro_df["group"] == "HC"
healthy_group = openneuro_df[healthy_idx]
patient_groups = openneuro_df[~healthy_idx]

# Load the healthy and patient data
healthy_clinical_data = NormData.from_dataframe(
    name="openneuro_healthy",
    dataframe=healthy_group,
    covariates=covariates,
    batch_effects=batch_effects,
    response_vars=response_variables,
    remove_Nan=True,
    remove_outliers=True,
)
patient_clinical_data = NormData.from_dataframe(
    name="openneuro_patient",
    dataframe=patient_groups,
    covariates=covariates,
    batch_effects=batch_effects,
    response_vars=response_variables,
    remove_Nan=True,
    remove_outliers=True,
)

# Ensure all batch effect values (sites) from both datasets are known before merging.
reference_norm_data.make_compatible(healthy_clinical_data)

# Merge the healthy data with the reference data
norm_train = reference_norm_data.merge(healthy_clinical_data)

# Check if all the data is compatible, meaning that the covariates, response variables, and batch effects are the same
if not norm_train.check_compatibility(patient_clinical_data):
    raise ValueError("The data is not compatible")
else:
    print("The data is compatible")
# Out:
# Process: 60478 - 2026-05-05 14:45:52 - Removed 0 NANs
# Process: 60478 - 2026-05-05 14:45:52 - Removed 1 outliers for lh_G_and_S_frontomargin
# Process: 60478 - 2026-05-05 14:45:52 - Removed 1 outliers
# Process: 60478 - 2026-05-05 14:45:52 - Dataset "openneuro_healthy" created.
#     - 58 observations
#     - 58 unique subjects
#     - 1 covariates
#     - 5 response variables
#     - 2 batch effects:
#     	site (2)
# 	sex (2)
#
# Process: 60478 - 2026-05-05 14:45:52 - Removed 0 NANs
# Process: 60478 - 2026-05-05 14:45:52 - Removed 1 outliers for lh_G_and_S_occipital_inf
# Process: 60478 - 2026-05-05 14:45:52 - Removed 1 outliers
# Process: 60478 - 2026-05-05 14:45:52 - Dataset "openneuro_patient" created.
#     - 61 observations
#     - 61 unique subjects
#     - 1 covariates
#     - 5 response variables
#     - 2 batch effects:
#     	site (2)
# 	sex (2)
#
# Process: 60478 - 2026-05-05 14:45:52 - Dataset "fcon1000_+_openneuro_healthy" created.
#     - 1134 observations
#     - 1134 unique subjects
#     - 1 covariates
#     - 5 response variables
#     - 2 batch effects:
#     	site (25)
# 	sex (2)
#
# The data is compatible

# %% [markdown]
# -----
#
# ### Train-test split
#
# The reference set is split into a train set and a test set. The train set is used to train the normative model, while the test set is used to assess the performance of the model. A trade-off has to be made between the size of the train set and the size of the test set. A larger train set will result in a more accurate normative model, but a larger test set will result in a more reliable performance assessment. We recommend using a 80%-20% or 70%-30% split for the train and test set, respectively.
#
# For a correct performance assessment, the test set should be as statistically similar as possible to the train set. Stratification of the train-test split ensures that the distribution of the batch effect values in the train and test set are similar.
#
# The function `NormData.train_test_split` will perform a stratified train-test split on the batch effect dimensions, using the `train_test_split` function from scikit-learn. The stratification is done on batch effect dimensions.

# %%
train, test = norm_train.train_test_split(
    splits=(0.8, 0.2), split_names=["train", "test"], random_state=42
)
print(len(train.observations))
print(len(test.observations))
# Out:
# 907
# 227

# %% [markdown]
# -----

# %% [markdown]
# ### Standardization
#
# As said before, the PCNtoolkit will store the standardization coefficients in the model object, so that the same scaling is applied to any new data that is used to make predictions. This also means that none of the data scaling has to be done manually, and that it is as simple as configuring the inscaler and outscaler in the `NormativeModel` object, which is what we will do in the next step.
#
# ## 1.3 Modelling 🥘
#
# -----
#
# ### The NormativeModel class
#
# The central class in the PCNtoolkit is the `NormativeModel` class. It has all functions that are required to build and use a normative model. Here we will list a few of the most important functions. For extensive documentation, please refer to the official documentation at https://predictive-clinical-neuroscience.github.io/pcntoolkit/
#
# ```NormativeModel.fit(data:NormData)```
#
# This function fits the normative model to the training data.
#
# ```NormativeModel.predict(data:NormData)```
#
# This function makes predictions on new data.
#
# ```NormativeModel.fit_predict(fit_data:NormData, predict_data:NormData)```
#
# This function fits the normative model to the training data and makes predictions on new data.
#
# ```NormativeModel.save(path:Optional[str]=None)```
#
# This function saves the normative model to a file. Uses the configured save path in the `NormativeModel` object, or the path argument if provided.
#
# ```NormativeModel.load(path:str)```
#
# This function loads a normative model from a file.
#
# ```NormativeModel.transfer(data:NormData)```
#
# This function transfers the normative model to a new dataset.
#
# ```NormativeModel.extend(data:NormData)```
#
# This function extends the normative model to a new dataset.
#
# ```NormativeModel.merge(save_dir:str, models:list[Union[NormativeModel, str]])```
#
# This function merges two or more normative models and saves the result as a new  `NormativeModel` object at the specified path, also returning the new `NormativeModel` object. Models can be passed as a list containing a number of `NormativeModel` objects or as a list of paths to saved `NormativeModel` objects, or a mix of both.
#
# ```NormativeModel.synthesize(data:NormData, n_samples:int, covariate_range_per_batch_effect:bool=True)```
#
# This function creates synthetic data that follows the learned data distribution. If `covariate_range_per_batch_effect` is `True`, the range from which the covariate values are sampled is different for each batch effect, and follows the distribution that was observed in the training data.
#
# ```NormativeModel.harmonize(data:NormData, reference_batch_effect:dict[str,str] | None= None)```
#
# This function harmonizes new data to the reference data distribution.

# %%
from pcntoolkit import NormativeModel, HBR

model = NormativeModel(
    template_regression_model=HBR(),  # The template regression model to use (note that we will elaborate on this next)
    savemodel=True,  # Whether to save the model after fitting -  defaults to True
    evaluate_model=True,  # Whether to evaluate the model after fitting -  defaults to True
    saveresults=True,  # Whether to save the results (Z_scores, centiles, logp, evaluation metrics) -  defaults to True
    saveplots=True,  # Whether to save the plots (centile curves and qq-plots) -  defaults to True
    save_dir="../out/models/main_workflow_model_default_HBR",  # The directory to save the model
    inscaler="standardize",  # The scaler to use for the covariates, defaults to standardize
    outscaler="standardize",  # The scaler to use for the response variables, defaults to standardize
    name="main_workflow_model_default_HBR",  # The name of the model
)

# %% [markdown]
# -----
#
# ### The RegressionModel class
#
# We currently only support the creation of univariate normative models in the PCNtoolkit. This means that each `NormativeModel` object contains a collection of `RegressionModel` objects. For each response variable, the `NormativeModel` class makes a copy of a template regression and fits it to the response variable. This template is what the user should provide when creating a `NormativeModel`.
#
# The `RegressionModel` type currently has two concrete implementations; Bayesian Linear Regression (BLR) and Hierarchical Bayesian Regression (HBR). Each has its pros and cons, and we will discuss some of the differences, and how to choose between them, in the next section.
#
#
# #### Bayesian Linear Regression (BLR)
#
# The BLR algorithm in its most basic form assumes that features are normally distributed, conditioned on the covariates. It also assumes a conjugate on the regression coefficients, and optimizes those coefficient using a gradient method based on Bishop's Pattern Recognition and Machine Learning (2006). The batch effects in BLR are modeled as fixed effects, they are encoded as dummy indicator variables and concatenated to the design matrix. Batch effects can be modeled in both the slope and the intercept. Heteroskedasticity is also possible, and also there we can have batch effects in the intercept of the variance (the variance when the covariates are 0), and slope of the variance (the strength of the effect the covariates have on the variance).
#
# Non-Gaussian features can also be modeled accurately by BLR if we learn an additional transformation - a warp - of the input features. The PCNtoolkit comes equiped with a number of options for warping, but the most useful one is the Sinh-Arcsinh mapping, which modulates the skewness and kurtosis of the distribution to which it is applied. With this warp, a wide range of non-Gaussian distributions can be covered.
#
# Finally, the BLR model also takes some arguments for the optimization. The defaults should work well in most cases. The below configuration creates a warped heteroskedastic model, which performs well in many cases. For more details about the arguments to this function, we refer to the documentation.

# %%
from pcntoolkit import BLR, BsplineBasisFunction

template_blr = BLR(
    name="template",
    basis_function_mean=BsplineBasisFunction(
        degree=3, nknots=5
    ),  # We use a B-spline basis expansion for the mean, so the predicted mean is a smooth function of the covariates
    fixed_effect=True,  # By setting fixed_effect=True, we \model offsets in the mean for each individual batch effect,
    fixed_effect_slope=True,  # We also model a fixed effect in the slope of the mean for each individual batch effect
    heteroskedastic=True,  # We want the variance to be a function of the covariates too
    warp_name="warpsinharcsinh",  # We configure a sinh-arcsinh warp, so we can model flexible non-gaussian distributions
)

# %% [markdown]
# #### Hierarchical Bayesian Regression (HBR)
#
# A HBR model assumes a hierarchical generative model on the data, and performs full posterior estimation using Markov Chain Monte-Carlo. Configuring a HBR model amounts to configuring the specifics of the generative model, which always consists of a likelihood and its parameters.
#
# Here we list the most important likelihoods supported by the PCNtoolkit, when to use them, the parameters they require, and the ranges of the parameters.
#
# <details>
# <summary> Normal Likelihood </summary>
#
#   - Use when the data is (approximately) normally distributed conditioned on the covariates.
#   - Parameters:
#     - `mu`
#       -  encodes the mean of the distribution
#       -  $\mu \in (-\infty, \infty)$
#     - `sigma` - encodes the variance of the distribution
#       - encodes the variance of the distribution
#       - $\sigma  \in [0, \infty)$
# </details>
#
# <details>
# <summary> SHASHb Likelihood </summary>
#
#   - Use then the data is not normally distributed, and unbounded.
#   - Parameters:
#     - `mu`
#       - encodes the mean of the distribution
#       - $\mu \in (-\infty, \infty)$
#     - `sigma`
#       - encodes the variance of the distribution
#       - $\sigma  \in [0, \infty)$
#     - `epsilon`
#       - ecodes the skewness of the distribution
#       - $\epsilon \in (-\infty, \infty)$
#     - `delta`
#       - encodes the kurtosis of the distribution
#       - $\delta \in [0, \infty)$
# </details>
#
# <details>
# <summary> Beta Likelihood </summary>
#
#   - Use when the data is not normally distributed, and falls within a strict range.
#   - Parameters:
#     - `alpha`
#     - encodes the tendency towards the upper limit of the range
#       - $\alpha \in [0, \infty)$
#     - `beta`
#       - encodes the tendency towards the lower limit of the range
#       - $\beta \in [0, \infty)$
# </details>
#
# For this example, we will use the normal likelihood, which has two easily interpretable parameters, mu and sigma. For more details on the parameterisation of the SHASHb and Beta likelihoods, please see the [PCNtoolkit documentation](https://pcntoolkit.readthedocs.io/en/latest/).
#
# With the choice of the likelihood made, we have to configure each of parameters' priors separately, which, in the PCNtoolkit, can be done with the `make_prior` function. For most models, there are multiple nested calls of `make_prior` required - it is a hierarchical model, after all. For a generic parameter $\theta$, we follow this schema:
#
# 1. Do we want $\theta$ to vary as a function of the covariates?
#    1. Yes:
#       - pass `linear=True`
#       - configure parameters `basis_function`, `slope` and `offset` according to this schema and pass them to the `make_prior` function.
#         <details>
#         <summary> Details on configuring linear HBR parameters</summary>
#
#         `Slope` and `offset` respectively correspond to $w$ and $\tau$ in the following equation:
#
#         \begin{align}
#         w_n &\sim p_w(w_n) \\
#         \tau_n &\sim p_\tau(\tau_n)\\
#         \theta_n &= w_n^T\phi(x_n) + \tau_n
#         \end{align}
#
#         Where $x_n$ is the $n$'th set of covariates, $\phi$ is the basis function.
#
#         As should be clear from the equations, $w$ and $\tau$ both have their own priors, $p_w$ and $p_\tau$. These should _not_ be linear, but may have a random effect, which is why the subscript $n$ indicates that they may differ for each datapoint.
#
#         </details>
#
#    2. No:
#       1. Do we want $\theta$ to have a batch effect?
#          1. Yes:
#             - pass `random=True`
#             - configure parameters `mu` and `sigma` according to this schema and pass them to the `make_prior` function.
#               <details>
#               <summary> Details on configuring random HBR parameters</summary>
#
#               Configuration of random parameters in the PCNtoolkit follows a non-centered schema to avoid Neal's funnel discussed here: [https://crackedbassoon.com/writing/funneling](https://crackedbassoon.com/writing/funneling). Essentially, parameters with a random effect vary around a common mean, and are further composed by a sum of group-specific offsets, which all follow normal distributions. For instance, a parameter with batch effects of site and sex is modeled as a sum of the common mean, the site-specific offset, and the sex-specific offset.
#
#
#
#
#               More formally,
#               - Let $\beta$ be the number of batch effect dimensions, i.e. for batch effects (site, sex), $\beta = 2$.
#               - Let $N$ denote the number of observations/datapoints.
#               - Let $v_b$ denote the number of unique batch effect values of the $b$'th batch effect dimension. I.e. if there are two unique sexes and five unique sites, $v_0 = 2$ and $v_1 = 5$.
#               - Let $Z$ denote the $N \times \beta$ matrix of batch effect indices.
#
#               Then:
#
#               \begin{align}
#                 \mu_{\theta} &\sim p_\mu(\mu_\theta)\\
#                 \sigma_{{\theta}_b} &\sim p_\sigma(\sigma_{{\theta}_b}) & \text{ where } p_\sigma(\theta') = 0 \text{ for all } \theta' \leq 0\\
#                 \nu_{{\theta}_b} &\sim \mathcal{N}(\nu_{{\theta}_b} \mid \mathbf{0}^{v_b}, \mathbf{I}^{v_b})\\
#                 \theta_n &= \mu_{\theta} + \sum_{b=1}^B \sigma_{{\theta}_b}\nu_{{\theta}_b}[Z_{n,b}]
#               \end{align}
#
#               Here we see that $\mu_\theta$ and each of the $\beta$ $\sigma$'s need their own priors. $\mu_\theta$ is the common mean. The offsets $\nu$ are sampled from a standard 1-d Gaussian, and scaled using $\sigma$. Sigma therefore encodes the standard deviation of the offsets, through a reparameterization. This is why, as we will see, the prior of $\sigma$ has to be strictly positive, which we can enforce using a mapping to the positive domain.
#
#               </details>
#
#          2. No:
#             - This is a single fixed parameter, identically modeled for each datapoint, without any linear or batch effects.
#             - pass the `dist_name` and `dist_params` arguments and optionally the `mapping` and `mapping_params` to `make_prior`.
#               <details>
#               <summary> Details on configuring single, fixed parameters </summary>
#
#                  Single, fixed parameters are sampled from a known distribution and directly used as likelihood parameters (such as $\mu$ and $\sigma$ for the normal likelihood), or as hierarchical parameters (such as $\sigma_\theta$ in random parameters, or $w_n$ in linear parameters). Thus, we will have to configure that known distribution, its parameters, and optionally a mapping if the parameter has to be strictly positive.
#
#                  The mapping can be any function $\mathbb{R} \to \mathbb{R^+}$, and it is parameterized by a 3-tuple $(a,b,c)$, which encode x-shift, scale, and y-shift respectively. For any mapping $f$, the mapped output $y$ is computed as $$y = f((x-a)/b)\cdot b + c.$$ The default values for $a$, $b$, and $c$ in the PCNtoolkit are 0, 1, and 0 naturally, such that $y=f(x)$. The PCNtoolkit allows passing either $(a,b,c)$ or $(a,b)$, in which $c$ will be taken to be 0.
#
#
#                  So, without a mapping, a single fixed $\theta$ is sampled as:
#
#                  \begin{align}
#                  \theta &\sim p_\theta(\theta)
#                  \end{align}
#
#                  And with a mapping, it is sampled as:
#
#                  \begin{align}
#                  \theta &\sim p_\theta(\theta)\\
#                  \theta^+ &= f((\theta-a)/b)\cdot b + c
#                  \end{align}
#
#
#
#           </details>
#
#
# Finally, to complete the configuration of the HBR model, we have to configure the sampler. The defaults sampler settings work well. Below is an example configurations, with all the defaults sampler parameters explicated.

# %%
from pcntoolkit import make_prior, BsplineBasisFunction, NormalLikelihood, HBR

mu = make_prior(
    # Mu is linear because we want to allow the mean to vary as a function of the covariates.
    linear=True,
    # The slope coefficients are assumed to be normally distributed, with a mean of 0 and a standard deviation of 2.
    slope=make_prior(dist_params=(0, 2)),
    # The intercept is random, because we expect the intercept to vary between sites and sexes.
    intercept=make_prior(
        random=True,
        # Mu is the mean of the intercept, which is normally distributed with a mean of 0 and a standard deviation of 1.
        mu=make_prior(dist_params=(0.0, 1.0)),
        # Sigma is the scale at which the intercepts vary. It is a positive parameter, so we have to map it to the positive domain.
        sigma=make_prior(
            dist_params=(3.0, 1.0),
            mapping="softplus",
            mapping_params=(0.0, 2.0),
        ),
    ),
    # We use a B-spline basis function to allow for non-linearity in the mean.
    basis_function=BsplineBasisFunction(basis_column=0, nknots=5, degree=3),
)
sigma = make_prior(
    # Sigma is also linear, because we want to allow the standard deviation to vary as a function of the covariates: heteroskedasticity.
    linear=True,
    # The slope coefficients are assumed to be normally distributed, with a mean of 0 and a standard deviation of 2.
    slope=make_prior(dist_params=(0.0, 2.0)),
    # The intercept is not random, because we assume the intercept of the variance to be the same for all sites and sexes.
    intercept=make_prior(dist_params=(3.0, 2.0)),
    # We use a B-spline basis function to allow for non-linearity in the standard deviation.
    basis_function=BsplineBasisFunction(basis_column=0, nknots=5, degree=3),
    # We use a softplus mapping to ensure that sigma is strictly positive.
    mapping="softplus",
    # We scale the softplus mapping by a factor of 3, to avoid spikes in the resulting density.
    # The parameters (a, b, c) provided to a mapping f are used as: f_abc(x) = f((x - a) / b) * b + c
    # This basically provides an affine transformation of the softplus function.
    # a -> horizontal shift
    # b -> scaling
    # c -> vertical shift
    # You can leave c out, and it will default to 0.
    mapping_params=(0.0, 2.0),
)

# Set the likelihood with the priors we just created.
likelihood = NormalLikelihood(mu, sigma)

template_hbr = HBR(
    name="template_hbr",
    # The likelihood we just created.
    likelihood=likelihood,
    ### Sampling parameters
    # The number of draws to sample from the posterior per chain.
    draws=1500,
    # The number of tuning steps to run.
    tune=500,
    # The number of cores to use for sampling.
    cores=4,
    # The number of MCMC chains to run.
    chains=4,
    # The sampler to use for the model.
    nuts_sampler="nutpie",
    # The initialisation method for the samples
    init="jitter+adapt_diag",
    # Whether to show a progress bar during the model fitting.
    progressbar=True,
)

# %% [markdown]
# ----
#
#
# ### Combining the NormativeModel and RegressionModel classes
#
# We already saw how to create a `NormativeModel`, but then we used the default HBR model. Now we will use the template HBR model that we just configured.

# %%
model = NormativeModel(
    template_regression_model=template_hbr,  # The HBR model we just configured
    save_dir="../out/models/main_workflow_model_HBR",  # The path where the model will be saved
)

# # Load the model (if already fitted)
# model = NormativeModel.load("../out/models/main_workflow_model_HBR")

# %% [markdown]
# -----
#
# ### Fitting the normative model to the data
#
# Now we have everything configured:
# 1. We selected the data
# 2. We prepared the data by preprocessing and splitting into train and test set
# 3. We configured the template regression model
# 4. We configured the normative model
#
# All we have to do is fit the model to the train set, and predict on the test set, which we can do in a single call to `fit_predict`. It will fit and save the model, make predictions on the train and test set, and also save those. By default, the model will also make plots and save those.

# %%
import time

start_time = time.time()
model.fit_predict(train, test)
end_time = time.time()
print(f"Time taken: {end_time - start_time} seconds")
# Out:
# Process: 60478 - 2026-05-05 14:46:22 - Fitting models on 5 response variables.
# Process: 60478 - 2026-05-05 14:46:22 - Fitting model for lh_G_and_S_frontomargin.
# <style>
#     :root {
#         --column-width-1: 40%; /* Progress column width */
#         --column-width-2: 15%; /* Chain column width */
#         --column-width-3: 15%; /* Divergences column width */
#         --column-width-4: 15%; /* Step Size column width */
#         --column-width-5: 15%; /* Gradients/Draw column width */
#     }
#
#     .nutpie {
#         max-width: 800px;
#         margin: 10px auto;
#         font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#         //color: #333;
#         //background-color: #fff;
#         padding: 10px;
#         box-shadow: 0 4px 6px rgba(0,0,0,0.1);
#         border-radius: 8px;
#         font-size: 14px; /* Smaller font size for a more compact look */
#     }
#     .nutpie table {
#         width: 100%;
#         border-collapse: collapse; /* Remove any extra space between borders */
#     }
#     .nutpie th, .nutpie td {
#         padding: 8px 10px; /* Reduce padding to make table more compact */
#         text-align: left;
#         border-bottom: 1px solid #888;
#     }
#     .nutpie th {
#         //background-color: #f0f0f0;
#     }
#
#     .nutpie th:nth-child(1) { width: var(--column-width-1); }
#     .nutpie th:nth-child(2) { width: var(--column-width-2); }
#     .nutpie th:nth-child(3) { width: var(--column-width-3); }
#     .nutpie th:nth-child(4) { width: var(--column-width-4); }
#     .nutpie th:nth-child(5) { width: var(--column-width-5); }
#
#     .nutpie progress {
#         width: 100%;
#         height: 15px; /* Smaller progress bars */
#         border-radius: 5px;
#     }
#     progress::-webkit-progress-bar {
#         background-color: #eee;
#         border-radius: 5px;
#     }
#     progress::-webkit-progress-value {
#         background-color: #5cb85c;
#         border-radius: 5px;
#     }
#     progress::-moz-progress-bar {
#         background-color: #5cb85c;
#         border-radius: 5px;
#     }
#     .nutpie .progress-cell {
#         width: 100%;
#     }
#
#     .nutpie p strong { font-size: 16px; font-weight: bold; }
#
#     @media (prefers-color-scheme: dark) {
#         .nutpie {
#             //color: #ddd;
#             //background-color: #1e1e1e;
#             box-shadow: 0 4px 6px rgba(0,0,0,0.2);
#         }
#         .nutpie table, .nutpie th, .nutpie td {
#             border-color: #555;
#             color: #ccc;
#         }
#         .nutpie th {
#             background-color: #2a2a2a;
#         }
#         .nutpie progress::-webkit-progress-bar {
#             background-color: #444;
#         }
#         .nutpie progress::-webkit-progress-value {
#             background-color: #3178c6;
#         }
#         .nutpie progress::-moz-progress-bar {
#             background-color: #3178c6;
#         }
#     }
# </style>
# <div class="nutpie">
#     <p><strong>Sampler Progress</strong></p>
#     <p>Total Chains: <span id="total-chains">4</span></p>
#     <p>Active Chains: <span id="active-chains">0</span></p>
#     <p>
#         Finished Chains:
#         <span id="active-chains">4</span>
#     </p>
#     <p>Sampling for now</p>
#     <p>
#         Estimated Time to Completion:
#         <span id="eta">now</span>
#     </p>
#
#     <progress
#         id="total-progress-bar"
#         max="8000"
#         value="8000">
#     </progress>
#     <table>
#         <thead>
#             <tr>
#                 <th>Progress</th>
#                 <th>Draws</th>
#                 <th>Divergences</th>
#                 <th>Step Size</th>
#                 <th>Gradients/Draw</th>
#             </tr>
#         </thead>
#         <tbody id="chain-details">
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="2000"
#                             value="2000">
#                         </progress>
#                     </td>
#                     <td>2000</td>
#                     <td>0</td>
#                     <td>0.20</td>
#                     <td>127</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="2000"
#                             value="2000">
#                         </progress>
#                     </td>
#                     <td>2000</td>
#                     <td>0</td>
#                     <td>0.18</td>
#                     <td>31</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="2000"
#                             value="2000">
#                         </progress>
#                     </td>
#                     <td>2000</td>
#                     <td>0</td>
#                     <td>0.19</td>
#                     <td>63</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="2000"
#                             value="2000">
#                         </progress>
#                     </td>
#                     <td>2000</td>
#                     <td>0</td>
#                     <td>0.18</td>
#                     <td>79</td>
#                 </tr>
#
#             </tr>
#         </tbody>
#     </table>
# </div>
# Process: 60478 - 2026-05-05 14:46:54 - Fitting model for lh_G_and_S_occipital_inf.
# <style>
#     :root {
#         --column-width-1: 40%; /* Progress column width */
#         --column-width-2: 15%; /* Chain column width */
#         --column-width-3: 15%; /* Divergences column width */
#         --column-width-4: 15%; /* Step Size column width */
#         --column-width-5: 15%; /* Gradients/Draw column width */
#     }
#
#     .nutpie {
#         max-width: 800px;
#         margin: 10px auto;
#         font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#         //color: #333;
#         //background-color: #fff;
#         padding: 10px;
#         box-shadow: 0 4px 6px rgba(0,0,0,0.1);
#         border-radius: 8px;
#         font-size: 14px; /* Smaller font size for a more compact look */
#     }
#     .nutpie table {
#         width: 100%;
#         border-collapse: collapse; /* Remove any extra space between borders */
#     }
#     .nutpie th, .nutpie td {
#         padding: 8px 10px; /* Reduce padding to make table more compact */
#         text-align: left;
#         border-bottom: 1px solid #888;
#     }
#     .nutpie th {
#         //background-color: #f0f0f0;
#     }
#
#     .nutpie th:nth-child(1) { width: var(--column-width-1); }
#     .nutpie th:nth-child(2) { width: var(--column-width-2); }
#     .nutpie th:nth-child(3) { width: var(--column-width-3); }
#     .nutpie th:nth-child(4) { width: var(--column-width-4); }
#     .nutpie th:nth-child(5) { width: var(--column-width-5); }
#
#     .nutpie progress {
#         width: 100%;
#         height: 15px; /* Smaller progress bars */
#         border-radius: 5px;
#     }
#     progress::-webkit-progress-bar {
#         background-color: #eee;
#         border-radius: 5px;
#     }
#     progress::-webkit-progress-value {
#         background-color: #5cb85c;
#         border-radius: 5px;
#     }
#     progress::-moz-progress-bar {
#         background-color: #5cb85c;
#         border-radius: 5px;
#     }
#     .nutpie .progress-cell {
#         width: 100%;
#     }
#
#     .nutpie p strong { font-size: 16px; font-weight: bold; }
#
#     @media (prefers-color-scheme: dark) {
#         .nutpie {
#             //color: #ddd;
#             //background-color: #1e1e1e;
#             box-shadow: 0 4px 6px rgba(0,0,0,0.2);
#         }
#         .nutpie table, .nutpie th, .nutpie td {
#             border-color: #555;
#             color: #ccc;
#         }
#         .nutpie th {
#             background-color: #2a2a2a;
#         }
#         .nutpie progress::-webkit-progress-bar {
#             background-color: #444;
#         }
#         .nutpie progress::-webkit-progress-value {
#             background-color: #3178c6;
#         }
#         .nutpie progress::-moz-progress-bar {
#             background-color: #3178c6;
#         }
#     }
# </style>
# <div class="nutpie">
#     <p><strong>Sampler Progress</strong></p>
#     <p>Total Chains: <span id="total-chains">4</span></p>
#     <p>Active Chains: <span id="active-chains">0</span></p>
#     <p>
#         Finished Chains:
#         <span id="active-chains">4</span>
#     </p>
#     <p>Sampling for now</p>
#     <p>
#         Estimated Time to Completion:
#         <span id="eta">now</span>
#     </p>
#
#     <progress
#         id="total-progress-bar"
#         max="8000"
#         value="8000">
#     </progress>
#     <table>
#         <thead>
#             <tr>
#                 <th>Progress</th>
#                 <th>Draws</th>
#                 <th>Divergences</th>
#                 <th>Step Size</th>
#                 <th>Gradients/Draw</th>
#             </tr>
#         </thead>
#         <tbody id="chain-details">
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="2000"
#                             value="2000">
#                         </progress>
#                     </td>
#                     <td>2000</td>
#                     <td>1</td>
#                     <td>0.18</td>
#                     <td>63</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="2000"
#                             value="2000">
#                         </progress>
#                     </td>
#                     <td>2000</td>
#                     <td>0</td>
#                     <td>0.21</td>
#                     <td>47</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="2000"
#                             value="2000">
#                         </progress>
#                     </td>
#                     <td>2000</td>
#                     <td>0</td>
#                     <td>0.20</td>
#                     <td>15</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="2000"
#                             value="2000">
#                         </progress>
#                     </td>
#                     <td>2000</td>
#                     <td>0</td>
#                     <td>0.19</td>
#                     <td>63</td>
#                 </tr>
#
#             </tr>
#         </tbody>
#     </table>
# </div>
# Process: 60478 - 2026-05-05 14:47:15 - Fitting model for lh_G_and_S_paracentral.
# <style>
#     :root {
#         --column-width-1: 40%; /* Progress column width */
#         --column-width-2: 15%; /* Chain column width */
#         --column-width-3: 15%; /* Divergences column width */
#         --column-width-4: 15%; /* Step Size column width */
#         --column-width-5: 15%; /* Gradients/Draw column width */
#     }
#
#     .nutpie {
#         max-width: 800px;
#         margin: 10px auto;
#         font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#         //color: #333;
#         //background-color: #fff;
#         padding: 10px;
#         box-shadow: 0 4px 6px rgba(0,0,0,0.1);
#         border-radius: 8px;
#         font-size: 14px; /* Smaller font size for a more compact look */
#     }
#     .nutpie table {
#         width: 100%;
#         border-collapse: collapse; /* Remove any extra space between borders */
#     }
#     .nutpie th, .nutpie td {
#         padding: 8px 10px; /* Reduce padding to make table more compact */
#         text-align: left;
#         border-bottom: 1px solid #888;
#     }
#     .nutpie th {
#         //background-color: #f0f0f0;
#     }
#
#     .nutpie th:nth-child(1) { width: var(--column-width-1); }
#     .nutpie th:nth-child(2) { width: var(--column-width-2); }
#     .nutpie th:nth-child(3) { width: var(--column-width-3); }
#     .nutpie th:nth-child(4) { width: var(--column-width-4); }
#     .nutpie th:nth-child(5) { width: var(--column-width-5); }
#
#     .nutpie progress {
#         width: 100%;
#         height: 15px; /* Smaller progress bars */
#         border-radius: 5px;
#     }
#     progress::-webkit-progress-bar {
#         background-color: #eee;
#         border-radius: 5px;
#     }
#     progress::-webkit-progress-value {
#         background-color: #5cb85c;
#         border-radius: 5px;
#     }
#     progress::-moz-progress-bar {
#         background-color: #5cb85c;
#         border-radius: 5px;
#     }
#     .nutpie .progress-cell {
#         width: 100%;
#     }
#
#     .nutpie p strong { font-size: 16px; font-weight: bold; }
#
#     @media (prefers-color-scheme: dark) {
#         .nutpie {
#             //color: #ddd;
#             //background-color: #1e1e1e;
#             box-shadow: 0 4px 6px rgba(0,0,0,0.2);
#         }
#         .nutpie table, .nutpie th, .nutpie td {
#             border-color: #555;
#             color: #ccc;
#         }
#         .nutpie th {
#             background-color: #2a2a2a;
#         }
#         .nutpie progress::-webkit-progress-bar {
#             background-color: #444;
#         }
#         .nutpie progress::-webkit-progress-value {
#             background-color: #3178c6;
#         }
#         .nutpie progress::-moz-progress-bar {
#             background-color: #3178c6;
#         }
#     }
# </style>
# <div class="nutpie">
#     <p><strong>Sampler Progress</strong></p>
#     <p>Total Chains: <span id="total-chains">4</span></p>
#     <p>Active Chains: <span id="active-chains">0</span></p>
#     <p>
#         Finished Chains:
#         <span id="active-chains">4</span>
#     </p>
#     <p>Sampling for now</p>
#     <p>
#         Estimated Time to Completion:
#         <span id="eta">now</span>
#     </p>
#
#     <progress
#         id="total-progress-bar"
#         max="8000"
#         value="8000">
#     </progress>
#     <table>
#         <thead>
#             <tr>
#                 <th>Progress</th>
#                 <th>Draws</th>
#                 <th>Divergences</th>
#                 <th>Step Size</th>
#                 <th>Gradients/Draw</th>
#             </tr>
#         </thead>
#         <tbody id="chain-details">
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="2000"
#                             value="2000">
#                         </progress>
#                     </td>
#                     <td>2000</td>
#                     <td>0</td>
#                     <td>0.17</td>
#                     <td>63</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="2000"
#                             value="2000">
#                         </progress>
#                     </td>
#                     <td>2000</td>
#                     <td>0</td>
#                     <td>0.20</td>
#                     <td>95</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="2000"
#                             value="2000">
#                         </progress>
#                     </td>
#                     <td>2000</td>
#                     <td>0</td>
#                     <td>0.19</td>
#                     <td>31</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="2000"
#                             value="2000">
#                         </progress>
#                     </td>
#                     <td>2000</td>
#                     <td>0</td>
#                     <td>0.18</td>
#                     <td>95</td>
#                 </tr>
#
#             </tr>
#         </tbody>
#     </table>
# </div>
# Process: 60478 - 2026-05-05 14:47:38 - Fitting model for lh_G_and_S_subcentral.
# <style>
#     :root {
#         --column-width-1: 40%; /* Progress column width */
#         --column-width-2: 15%; /* Chain column width */
#         --column-width-3: 15%; /* Divergences column width */
#         --column-width-4: 15%; /* Step Size column width */
#         --column-width-5: 15%; /* Gradients/Draw column width */
#     }
#
#     .nutpie {
#         max-width: 800px;
#         margin: 10px auto;
#         font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#         //color: #333;
#         //background-color: #fff;
#         padding: 10px;
#         box-shadow: 0 4px 6px rgba(0,0,0,0.1);
#         border-radius: 8px;
#         font-size: 14px; /* Smaller font size for a more compact look */
#     }
#     .nutpie table {
#         width: 100%;
#         border-collapse: collapse; /* Remove any extra space between borders */
#     }
#     .nutpie th, .nutpie td {
#         padding: 8px 10px; /* Reduce padding to make table more compact */
#         text-align: left;
#         border-bottom: 1px solid #888;
#     }
#     .nutpie th {
#         //background-color: #f0f0f0;
#     }
#
#     .nutpie th:nth-child(1) { width: var(--column-width-1); }
#     .nutpie th:nth-child(2) { width: var(--column-width-2); }
#     .nutpie th:nth-child(3) { width: var(--column-width-3); }
#     .nutpie th:nth-child(4) { width: var(--column-width-4); }
#     .nutpie th:nth-child(5) { width: var(--column-width-5); }
#
#     .nutpie progress {
#         width: 100%;
#         height: 15px; /* Smaller progress bars */
#         border-radius: 5px;
#     }
#     progress::-webkit-progress-bar {
#         background-color: #eee;
#         border-radius: 5px;
#     }
#     progress::-webkit-progress-value {
#         background-color: #5cb85c;
#         border-radius: 5px;
#     }
#     progress::-moz-progress-bar {
#         background-color: #5cb85c;
#         border-radius: 5px;
#     }
#     .nutpie .progress-cell {
#         width: 100%;
#     }
#
#     .nutpie p strong { font-size: 16px; font-weight: bold; }
#
#     @media (prefers-color-scheme: dark) {
#         .nutpie {
#             //color: #ddd;
#             //background-color: #1e1e1e;
#             box-shadow: 0 4px 6px rgba(0,0,0,0.2);
#         }
#         .nutpie table, .nutpie th, .nutpie td {
#             border-color: #555;
#             color: #ccc;
#         }
#         .nutpie th {
#             background-color: #2a2a2a;
#         }
#         .nutpie progress::-webkit-progress-bar {
#             background-color: #444;
#         }
#         .nutpie progress::-webkit-progress-value {
#             background-color: #3178c6;
#         }
#         .nutpie progress::-moz-progress-bar {
#             background-color: #3178c6;
#         }
#     }
# </style>
# <div class="nutpie">
#     <p><strong>Sampler Progress</strong></p>
#     <p>Total Chains: <span id="total-chains">4</span></p>
#     <p>Active Chains: <span id="active-chains">0</span></p>
#     <p>
#         Finished Chains:
#         <span id="active-chains">4</span>
#     </p>
#     <p>Sampling for now</p>
#     <p>
#         Estimated Time to Completion:
#         <span id="eta">now</span>
#     </p>
#
#     <progress
#         id="total-progress-bar"
#         max="8000"
#         value="8000">
#     </progress>
#     <table>
#         <thead>
#             <tr>
#                 <th>Progress</th>
#                 <th>Draws</th>
#                 <th>Divergences</th>
#                 <th>Step Size</th>
#                 <th>Gradients/Draw</th>
#             </tr>
#         </thead>
#         <tbody id="chain-details">
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="2000"
#                             value="2000">
#                         </progress>
#                     </td>
#                     <td>2000</td>
#                     <td>0</td>
#                     <td>0.20</td>
#                     <td>31</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="2000"
#                             value="2000">
#                         </progress>
#                     </td>
#                     <td>2000</td>
#                     <td>0</td>
#                     <td>0.19</td>
#                     <td>31</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="2000"
#                             value="2000">
#                         </progress>
#                     </td>
#                     <td>2000</td>
#                     <td>0</td>
#                     <td>0.17</td>
#                     <td>31</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="2000"
#                             value="2000">
#                         </progress>
#                     </td>
#                     <td>2000</td>
#                     <td>0</td>
#                     <td>0.19</td>
#                     <td>63</td>
#                 </tr>
#
#             </tr>
#         </tbody>
#     </table>
# </div>
# Process: 60478 - 2026-05-05 14:48:00 - Fitting model for lh_G_and_S_transv_frontopol.
# <style>
#     :root {
#         --column-width-1: 40%; /* Progress column width */
#         --column-width-2: 15%; /* Chain column width */
#         --column-width-3: 15%; /* Divergences column width */
#         --column-width-4: 15%; /* Step Size column width */
#         --column-width-5: 15%; /* Gradients/Draw column width */
#     }
#
#     .nutpie {
#         max-width: 800px;
#         margin: 10px auto;
#         font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#         //color: #333;
#         //background-color: #fff;
#         padding: 10px;
#         box-shadow: 0 4px 6px rgba(0,0,0,0.1);
#         border-radius: 8px;
#         font-size: 14px; /* Smaller font size for a more compact look */
#     }
#     .nutpie table {
#         width: 100%;
#         border-collapse: collapse; /* Remove any extra space between borders */
#     }
#     .nutpie th, .nutpie td {
#         padding: 8px 10px; /* Reduce padding to make table more compact */
#         text-align: left;
#         border-bottom: 1px solid #888;
#     }
#     .nutpie th {
#         //background-color: #f0f0f0;
#     }
#
#     .nutpie th:nth-child(1) { width: var(--column-width-1); }
#     .nutpie th:nth-child(2) { width: var(--column-width-2); }
#     .nutpie th:nth-child(3) { width: var(--column-width-3); }
#     .nutpie th:nth-child(4) { width: var(--column-width-4); }
#     .nutpie th:nth-child(5) { width: var(--column-width-5); }
#
#     .nutpie progress {
#         width: 100%;
#         height: 15px; /* Smaller progress bars */
#         border-radius: 5px;
#     }
#     progress::-webkit-progress-bar {
#         background-color: #eee;
#         border-radius: 5px;
#     }
#     progress::-webkit-progress-value {
#         background-color: #5cb85c;
#         border-radius: 5px;
#     }
#     progress::-moz-progress-bar {
#         background-color: #5cb85c;
#         border-radius: 5px;
#     }
#     .nutpie .progress-cell {
#         width: 100%;
#     }
#
#     .nutpie p strong { font-size: 16px; font-weight: bold; }
#
#     @media (prefers-color-scheme: dark) {
#         .nutpie {
#             //color: #ddd;
#             //background-color: #1e1e1e;
#             box-shadow: 0 4px 6px rgba(0,0,0,0.2);
#         }
#         .nutpie table, .nutpie th, .nutpie td {
#             border-color: #555;
#             color: #ccc;
#         }
#         .nutpie th {
#             background-color: #2a2a2a;
#         }
#         .nutpie progress::-webkit-progress-bar {
#             background-color: #444;
#         }
#         .nutpie progress::-webkit-progress-value {
#             background-color: #3178c6;
#         }
#         .nutpie progress::-moz-progress-bar {
#             background-color: #3178c6;
#         }
#     }
# </style>
# <div class="nutpie">
#     <p><strong>Sampler Progress</strong></p>
#     <p>Total Chains: <span id="total-chains">4</span></p>
#     <p>Active Chains: <span id="active-chains">0</span></p>
#     <p>
#         Finished Chains:
#         <span id="active-chains">4</span>
#     </p>
#     <p>Sampling for now</p>
#     <p>
#         Estimated Time to Completion:
#         <span id="eta">now</span>
#     </p>
#
#     <progress
#         id="total-progress-bar"
#         max="8000"
#         value="8000">
#     </progress>
#     <table>
#         <thead>
#             <tr>
#                 <th>Progress</th>
#                 <th>Draws</th>
#                 <th>Divergences</th>
#                 <th>Step Size</th>
#                 <th>Gradients/Draw</th>
#             </tr>
#         </thead>
#         <tbody id="chain-details">
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="2000"
#                             value="2000">
#                         </progress>
#                     </td>
#                     <td>2000</td>
#                     <td>0</td>
#                     <td>0.20</td>
#                     <td>31</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="2000"
#                             value="2000">
#                         </progress>
#                     </td>
#                     <td>2000</td>
#                     <td>0</td>
#                     <td>0.19</td>
#                     <td>63</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="2000"
#                             value="2000">
#                         </progress>
#                     </td>
#                     <td>2000</td>
#                     <td>0</td>
#                     <td>0.17</td>
#                     <td>31</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="2000"
#                             value="2000">
#                         </progress>
#                     </td>
#                     <td>2000</td>
#                     <td>0</td>
#                     <td>0.20</td>
#                     <td>31</td>
#                 </tr>
#
#             </tr>
#         </tbody>
#     </table>
# </div>
# Process: 60478 - 2026-05-05 14:48:22 - Saving model to:
# 	../out/models/main_workflow_model_HBR.
# Process: 60478 - 2026-05-05 14:48:23 - Making predictions on 5 response variables.
# Process: 60478 - 2026-05-05 14:48:23 - Computing z-scores for 5 response variables.
# Process: 60478 - 2026-05-05 14:48:23 - Computing z-scores for lh_G_and_S_transv_frontopol.
# Sampling: []
# Process: 60478 - 2026-05-05 14:48:24 - Computing z-scores for lh_G_and_S_frontomargin.
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:48:26 - Computing z-scores for lh_G_and_S_paracentral.
# Sampling: []
# Process: 60478 - 2026-05-05 14:48:27 - Computing z-scores for lh_G_and_S_occipital_inf.
# Sampling: []
# Process: 60478 - 2026-05-05 14:48:28 - Computing z-scores for lh_G_and_S_subcentral.
# Sampling: []
# Process: 60478 - 2026-05-05 14:48:28 - Computing centiles for 5 response variables.
# Process: 60478 - 2026-05-05 14:48:28 - Computing centiles for lh_G_and_S_transv_frontopol.
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:48:33 - Computing centiles for lh_G_and_S_frontomargin.
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:48:38 - Computing centiles for lh_G_and_S_paracentral.
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:48:42 - Computing centiles for lh_G_and_S_occipital_inf.
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:48:46 - Computing centiles for lh_G_and_S_subcentral.
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:48:51 - Computing log-probabilities for 5 response variables.
# Process: 60478 - 2026-05-05 14:48:51 - Computing log-probabilities for 5 response variables.
# Process: 60478 - 2026-05-05 14:48:51 - Computing log-probabilities for lh_G_and_S_transv_frontopol.
# Process: 60478 - 2026-05-05 14:48:52 - Computing log-probabilities for lh_G_and_S_frontomargin.
# Process: 60478 - 2026-05-05 14:48:53 - Computing log-probabilities for lh_G_and_S_paracentral.
# Process: 60478 - 2026-05-05 14:48:55 - Computing log-probabilities for lh_G_and_S_occipital_inf.
# Process: 60478 - 2026-05-05 14:48:56 - Computing log-probabilities for lh_G_and_S_subcentral.
# Sampling: []
# Process: 60478 - 2026-05-05 14:48:57 - Computing yhat for 5 response variables.
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# /Users/andmar/sfw/anaconda3/envs/py312dev/lib/python3.12/site-packages/pcntoolkit/dataio/norm_data.py:1178: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   subject_ids = subject_ids.stack(level="centile")
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:02 - Dataset "centile" created.
#     - 150 observations
#     - 150 unique subjects
#     - 1 covariates
#     - 5 response variables
#     - 2 batch effects:
#     	site (1)
# 	sex (1)
#
# Process: 60478 - 2026-05-05 14:49:02 - Computing centiles for 5 response variables.
# Process: 60478 - 2026-05-05 14:49:02 - Computing centiles for lh_G_and_S_transv_frontopol.
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:05 - Computing centiles for lh_G_and_S_frontomargin.
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:08 - Computing centiles for lh_G_and_S_paracentral.
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:10 - Computing centiles for lh_G_and_S_occipital_inf.
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:13 - Computing centiles for lh_G_and_S_subcentral.
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:15 - Harmonizing data on 5 response variables.
# Process: 60478 - 2026-05-05 14:49:15 - Harmonizing data for lh_G_and_S_transv_frontopol.
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:18 - Harmonizing data for lh_G_and_S_frontomargin.
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:19 - Harmonizing data for lh_G_and_S_paracentral.
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:21 - Harmonizing data for lh_G_and_S_occipital_inf.
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:23 - Harmonizing data for lh_G_and_S_subcentral.
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:26 - Making predictions on 5 response variables.
# Process: 60478 - 2026-05-05 14:49:26 - Computing z-scores for 5 response variables.
# Process: 60478 - 2026-05-05 14:49:26 - Computing z-scores for lh_G_and_S_transv_frontopol.
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:27 - Computing z-scores for lh_G_and_S_frontomargin.
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:27 - Computing z-scores for lh_G_and_S_paracentral.
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:28 - Computing z-scores for lh_G_and_S_occipital_inf.
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:28 - Computing z-scores for lh_G_and_S_subcentral.
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:29 - Computing centiles for 5 response variables.
# Process: 60478 - 2026-05-05 14:49:29 - Computing centiles for lh_G_and_S_transv_frontopol.
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:32 - Computing centiles for lh_G_and_S_frontomargin.
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:35 - Computing centiles for lh_G_and_S_paracentral.
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:38 - Computing centiles for lh_G_and_S_occipital_inf.
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:40 - Computing centiles for lh_G_and_S_subcentral.
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:44 - Computing log-probabilities for 5 response variables.
# Process: 60478 - 2026-05-05 14:49:44 - Computing log-probabilities for 5 response variables.
# Process: 60478 - 2026-05-05 14:49:44 - Computing log-probabilities for lh_G_and_S_transv_frontopol.
# Process: 60478 - 2026-05-05 14:49:44 - Computing log-probabilities for lh_G_and_S_frontomargin.
# Process: 60478 - 2026-05-05 14:49:45 - Computing log-probabilities for lh_G_and_S_paracentral.
# Process: 60478 - 2026-05-05 14:49:45 - Computing log-probabilities for lh_G_and_S_occipital_inf.
# Process: 60478 - 2026-05-05 14:49:46 - Computing log-probabilities for lh_G_and_S_subcentral.
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:47 - Computing yhat for 5 response variables.
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# /Users/andmar/sfw/anaconda3/envs/py312dev/lib/python3.12/site-packages/pcntoolkit/dataio/norm_data.py:1178: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   subject_ids = subject_ids.stack(level="centile")
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:50 - Dataset "centile" created.
#     - 150 observations
#     - 150 unique subjects
#     - 1 covariates
#     - 5 response variables
#     - 2 batch effects:
#     	site (1)
# 	sex (1)
#
# Process: 60478 - 2026-05-05 14:49:50 - Computing centiles for 5 response variables.
# Process: 60478 - 2026-05-05 14:49:50 - Computing centiles for lh_G_and_S_transv_frontopol.
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:53 - Computing centiles for lh_G_and_S_frontomargin.
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:56 - Computing centiles for lh_G_and_S_paracentral.
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:49:58 - Computing centiles for lh_G_and_S_occipital_inf.
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:50:01 - Computing centiles for lh_G_and_S_subcentral.
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:50:04 - Harmonizing data on 5 response variables.
# Process: 60478 - 2026-05-05 14:50:04 - Harmonizing data for lh_G_and_S_transv_frontopol.
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:50:05 - Harmonizing data for lh_G_and_S_frontomargin.
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:50:06 - Harmonizing data for lh_G_and_S_paracentral.
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:50:07 - Harmonizing data for lh_G_and_S_occipital_inf.
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:50:08 - Harmonizing data for lh_G_and_S_subcentral.
# Sampling: []
# Time taken: 228.32426595687866 seconds

# %% [markdown]
# -----
#
# ### [OPTIONAL] Fitting the normative model using a cluster
#
# For large datasets (either in terms of the number of samples or models) fitting models sequentially can be quite time consuming. If you have access to a Torque or Slurm cluster, operations such as `fit_predict` can be parallelised by using the `Runner` class. This will do the same tasks as in the previous step in a distributed fashion. This is a little more involved than in the previous step. For example, you need to specify the python executable and time and memory limits for each job. You can also specify the number of batches to split the workload into. Here we will use a slurm cluster, using one model per batch with 12 hours max run time and 2GB memory per job. This can be achieved in the following way:

# %%
# This section is optional and should run in a HPC cluster (not on your local PC)
RUN_OPTIONAL = False

if RUN_OPTIONAL:
    
    import os
    import sys

    from pcntoolkit import Runner

    # get path to python executable
    venv_path = os.path.join(os.path.dirname(os.path.dirname(sys.executable)))

    # configure runner
    runner = Runner(
        cross_validate=False,
        parallelize=True, 
        n_batches = len(reference_norm_data.response_vars), 

        environment=venv_path,
        job_type="slurm", 
        time_limit="12:00:00",
        memory = "2GB",
        n_cores=1,
        log_dir="../out/models/main_workflow_model_HBR/logs/",
        temp_dir="../out/models/main_workflow_model_HBR/tmp/",
        #preamble = "<commands to run before the job starts>", 
    )

    runner.fit_predict(model, train, train, observe=False)

# %% [markdown]
# ### Model evaluation and convergence diagnostics
#
# After fitting the model, we inspect the posterior samples and diagnostics to make sure everything behaved as expected.
# We'll look at both numerical summaries (e.g. $\hat{R}$, effective sample sizes) and visual checks like traceplots.
#
# Across the 74 estimated parameters — slopes, site and sex offsets, and scale parameters — convergence looks excellent.
# All $\hat{R}$ values are close to **1.00**, and the bulk and tail effective sample sizes (ESS) are generally high (median $\approx$ 4200 and median $\approx$ 7000 respectively.).
# Monte Carlo standard errors are tiny compared to the posterior standard deviations, which means the chains mixed well and ran long enough.
#
# | Metric          | Median | IQR             |
# |-----------------|:------:|:----------------|
# | Posterior mean  | -0.05  | -0.41–0.36      |
# | Posterior SD    |  0.27  | 0.19–0.39       |
# | MCSE (mean)     | 0.003  | 0.002–0.006     |
# | MCSE (sd)       | 0.004  | 0.003–0.006     |
# | ESS (bulk)      | 7038   | 3173–8281       |
# | ESS (tail)      | 4204   | 3635–4608       |
# | $\hat{R}$              | 1.000  | 1.000–1.000     |
#
# Below are the traceplots of the model parameters. Each line style represents one MCMC chain, and each color one covariate or random effect. You can see that the chains overlap nicely and explore the same region of the posterior — exactly what you want to see if the sampler has converged properly.

# %%
import arviz as az
import matplotlib.pyplot as plt
from pathlib import Path

az.rcParams["plot.max_subplots"] = 200

model_dir = Path("../out/models/main_workflow_model_HBR/model")

for feature_dir in model_dir.iterdir():
    if feature_dir.is_dir():
        idata = az.from_netcdf(feature_dir / "idata.nc")
        display(az.summary(idata).describe())
        az.plot_trace(idata, figure_kwargs={"figsize": (7, 15)})
        plt.tight_layout()
        plt.show()
# Out:
#             mean         sd     hdi_3%    hdi_97%  mcse_mean    mcse_sd  \
# count  99.000000  99.000000  99.000000  99.000000  99.000000  99.000000
# mean   -0.068051   0.411374  -0.845586   0.694545   0.007273   0.005889
# std     0.700762   0.393837   1.006905   1.024368   0.008965   0.005460
# min    -1.646000   0.011000  -3.995000  -0.952000   0.000000   0.000000
# 25%    -0.421500   0.195500  -1.328500   0.073000   0.002000   0.003000
# 50%    -0.088000   0.276000  -0.623000   0.380000   0.003000   0.004000
# 75%     0.304000   0.389500  -0.104000   1.115000   0.007000   0.006000
# max     2.742000   1.927000   0.674000   4.533000   0.040000   0.023000
#
#            ess_bulk     ess_tail  r_hat
# count     99.000000    99.000000   99.0
# mean    5919.101010  3964.505051    1.0
# std     2812.014009   870.070609    0.0
# min      930.000000  1372.000000    1.0
# 25%     3261.500000  3626.500000    1.0
# 50%     6716.000000  4182.000000    1.0
# 75%     8283.000000  4461.000000    1.0
# max    10438.000000  5390.000000    1.0
#             mean         sd     hdi_3%    hdi_97%  mcse_mean    mcse_sd  \
# count  99.000000  99.000000  99.000000  99.000000  99.000000  99.000000
# mean   -0.061434   0.424515  -0.854253   0.732828   0.007434   0.006131
# std     0.639023   0.385746   0.989541   0.934262   0.009079   0.005398
# min    -1.970000   0.012000  -4.148000  -0.905000   0.000000   0.000000
# 25%    -0.384500   0.200500  -1.188500   0.188500   0.002000   0.003000
# 50%    -0.096000   0.316000  -0.686000   0.435000   0.004000   0.005000
# 75%     0.310500   0.402500  -0.110000   1.225500   0.006000   0.006000
# max     2.746000   1.917000   0.808000   4.660000   0.038000   0.024000
#
#           ess_bulk     ess_tail      r_hat
# count    99.000000    99.000000  99.000000
# mean   6174.515152  4013.222222   1.000202
# std    2750.125731   888.850594   0.001414
# min     933.000000  1362.000000   1.000000
# 25%    4010.000000  3742.000000   1.000000
# 50%    7083.000000  4194.000000   1.000000
# 75%    8419.000000  4571.000000   1.000000
# max    9811.000000  5556.000000   1.010000
#             mean         sd     hdi_3%    hdi_97%  mcse_mean    mcse_sd  \
# count  99.000000  99.000000  99.000000  99.000000  99.000000  99.000000
# mean   -0.080303   0.380545  -0.792061   0.627778   0.007232   0.005455
# std     0.783002   0.410988   1.095887   1.098363   0.008853   0.005666
# min    -3.236000   0.009000  -5.542000  -0.850000   0.000000   0.000000
# 25%    -0.587500   0.179500  -1.259000  -0.147500   0.002000   0.002500
# 50%    -0.017000   0.226000  -0.648000   0.449000   0.004000   0.003000
# 75%     0.496000   0.307000  -0.005500   1.051500   0.006500   0.004000
# max     2.765000   1.891000   0.882000   4.701000   0.036000   0.023000
#
#            ess_bulk     ess_tail  r_hat
# count     99.000000    99.000000   99.0
# mean    5221.595960  3673.565657    1.0
# std     3009.226146   944.204742    0.0
# min      892.000000  1348.000000    1.0
# 25%     2197.500000  3066.000000    1.0
# 50%     5317.000000  3674.000000    1.0
# 75%     8190.000000  4426.000000    1.0
# max    10141.000000  5571.000000    1.0
#             mean         sd     hdi_3%    hdi_97%  mcse_mean    mcse_sd  \
# count  99.000000  99.000000  99.000000  99.000000  99.000000  99.000000
# mean   -0.018798   0.404485  -0.779535   0.736879   0.006980   0.005848
# std     0.717620   0.400796   1.064690   1.032927   0.008531   0.005592
# min    -1.796000   0.012000  -4.209000  -0.680000   0.000000   0.000000
# 25%    -0.278500   0.184500  -0.974500   0.149500   0.002000   0.003000
# 50%     0.002000   0.264000  -0.467000   0.438000   0.003000   0.004000
# 75%     0.265000   0.369000  -0.097500   1.070000   0.007000   0.006000
# max     2.745000   1.935000   0.852000   4.754000   0.034000   0.024000
#
#           ess_bulk     ess_tail      r_hat
# count    99.000000    99.000000  99.000000
# mean   6007.646465  4021.989899   1.000101
# std    2578.301040   857.750457   0.001005
# min     961.000000  1315.000000   1.000000
# 25%    3683.500000  3773.000000   1.000000
# 50%    6704.000000  4143.000000   1.000000
# 75%    8086.500000  4572.000000   1.000000
# max    9708.000000  5492.000000   1.010000
#             mean         sd     hdi_3%    hdi_97%  mcse_mean    mcse_sd  \
# count  99.000000  99.000000  99.000000  99.000000  99.000000  99.000000
# mean   -0.015394   0.400798  -0.763434   0.734384   0.007232   0.005616
# std     0.721629   0.400295   1.026213   1.069201   0.008878   0.005420
# min    -1.393000   0.011000  -3.870000  -0.554000   0.000000   0.000000
# 25%    -0.387000   0.186500  -1.234000   0.025500   0.002000   0.003000
# 50%    -0.044000   0.266000  -0.483000   0.379000   0.004000   0.004000
# 75%     0.426000   0.346500  -0.058000   1.112500   0.006000   0.005000
# max     2.756000   1.956000   1.093000   4.675000   0.035000   0.025000
#
#            ess_bulk     ess_tail      r_hat
# count     99.000000    99.000000  99.000000
# mean    5716.232323  3983.424242   1.000101
# std     2759.320849   876.459344   0.001005
# min      849.000000  1157.000000   1.000000
# 25%     3088.500000  3721.000000   1.000000
# 50%     6506.000000  4171.000000   1.000000
# 75%     7966.500000  4580.500000   1.000000
# max    10634.000000  5342.000000   1.010000

# %% [markdown]
# We can also interpret some of the plots on the LHS. For instance, in the bottom `sex_offset_intercept_mu` plot, we see the learned difference between the sexes, and in the `site_offset_intercept_mu` plot, we see the learned individual effects for each site. For larger sites, the estimations are more certain.
#
# #### Saving diagnostics
#
# This code iterates over all fitted features, computes the diagnostic summary for each, and saves an aggregated table (diagnostics_summary.csv) for later inspection:

# %%
import arviz as az
import pandas as pd
from pathlib import Path

model_dir = Path("../out/models/main_workflow_model_HBR/model")
diagnostics = []

for feature_dir in model_dir.iterdir():
    if feature_dir.is_dir():
        idata = az.from_netcdf(feature_dir / "idata.nc")
        summary = az.summary(idata, var_names=None)
        summary["feature"] = feature_dir.name
        diagnostics.append(summary)

diag_table = pd.concat(diagnostics)
diag_table.to_csv("../out/models/main_workflow_model_HBR/results/diagnostics_summary.csv")
diag_table.describe()
# Out:
#              mean          sd      hdi_3%     hdi_97%   mcse_mean     mcse_sd  \
# count  495.000000  495.000000  495.000000  495.000000  495.000000  495.000000
# mean    -0.048796    0.404343   -0.806974    0.705283    0.007230    0.005788
# std      0.711498    0.397065    1.033803    1.029973    0.008828    0.005491
# min     -3.236000    0.009000   -5.542000   -0.952000    0.000000    0.000000
# 25%     -0.407000    0.189500   -1.243500    0.062000    0.002000    0.003000
# 50%     -0.045000    0.266000   -0.570000    0.400000    0.004000    0.004000
# 75%      0.377500    0.388000   -0.063000    1.137500    0.007000    0.006000
# max      2.765000    1.956000    1.093000    4.754000    0.040000    0.025000
#
#            ess_bulk     ess_tail       r_hat
# count    495.000000   495.000000  495.000000
# mean    5807.818182  3931.341414    1.000081
# std     2793.327479   893.974193    0.000896
# min      849.000000  1157.000000    1.000000
# 25%     3006.500000  3594.000000    1.000000
# 50%     6590.000000  4119.000000    1.000000
# 75%     8183.500000  4551.000000    1.000000
# max    10634.000000  5571.000000    1.010000

# %% [markdown]
# ## 1.4 Evaluation 🍲
#
# The PCNtoolkit helps the user evaluating their models by saving informative plots and a dataframe with evaluation metrics. These can be found in the model save directory under `plots` and `results` respectively.
#
# ### Evaluation metrics and their meaning
#
# The table below provides an overview of the evaluation metrics provided by the PCNtoolkit.
#
# The rightmost column indicates whether the metric is computed using only the expected value of a feature, $\hat{y}$. Because a normative model not only estimates the expected value, but also the variance and sometimes the shape of the distribution, the metrics that are marked with 'Yes' in this column should not be assigned too much weight. See section [2.2](2.2_model_comparison.ipynb) for a more in-depth discussion.
#
# | Abbreviation | Full Name and useful link                     | What it measures                                                                 | Interpretation                                                                 |  Mean-based |
# |--------------|----------------------------------------|----------------------------------------------------------------------------------|--------------------------------------------------------------------------------|---|
# | EXPV         | [Explained Variance](https://en.wikipedia.org/wiki/Explained_variation)                    | Proportion of variance in the data explained by the model (similar to R², but can differ). | Closer to **1** = better (0 means no variance explained, negative means worse than mean predictor)| Yes |
# | MACE         | [Mean Absolute Centile Error](https://www.biorxiv.org/content/biorxiv/early/2025/06/25/2025.06.23.660997.full.pdf)         | Average absolute deviation of predictions from targets expressed in percentiles.  | Closer to **0** = better (0 means perfect percentile alignment, higher means worse calibration). | No |
# | MAPE         | [Mean Absolute Percentage Error](https://en.wikipedia.org/wiki/Mean_absolute_percentage_error)        | Average of absolute percentage errors between prediction and true values.         | Closer to **0%** = better (can blow up if actual values are close to 0). | No |
# | MSLL         | [Mean Standardized Log Loss](https://direct.mit.edu/books/oa-monograph-pdf/2514321/book_9780262256834.pdf)            | Compares model log-likelihood to a baseline, standardized by data variance.       | **Lower** is better (0 = same as baseline, negative = better than baseline, positive = worse). | Yes |
# | NLL          | [Negative Log-Likelihood](https://docs.pytorch.org/docs/stable/generated/torch.nn.NLLLoss.html)                | Likelihood-based measure of model fit.                          | **Lower** is better (0 = perfect likelihood, large positive = poor fit). | No |
# | R2           | [Coefficient of Determination (R²)](https://en.wikipedia.org/wiki/Coefficient_of_determination)     | Fraction of variance in target explained by the model.                            | Closer to **1** = better (0 means no variance explained, negative means worse than mean predictor). | Yes |
# | RMSE         | [Root Mean Squared Error](https://en.wikipedia.org/wiki/Root_mean_square_deviation)                | Square root of the mean squared difference between predictions and true values.   | Closer to **0** = better (represents error in original units of the target). | Yes |
# | Rho          | [Pearson Correlation Coefficient (ρ)](https://en.wikipedia.org/wiki/Pearson_correlation_coefficient)   | Linear correlation between predicted and true values.                             | Closer to **1** or **-1** = stronger correlation (0 = no linear correlation). | No |
# | Rho_p        | [p-value for Pearson’s ρ](https://en.wikipedia.org/wiki/Pearson_correlation_coefficient)            | Statistical significance of the correlation.                                      | Closer to **0** = stronger evidence of correlation (usually p < 0.05 is significant). | No |
# | SMSE         | [Standardized Mean Squared Error](https://en.wikipedia.org/wiki/Mean_squared_error)        | MSE normalized by the variance of the true data (relative measure of fit).        | Closer to **0** = better (1 = as bad as predicting the mean, >1 = worse than mean predictor). | Yes  |
# | ShapiroW     | [Shapiro–Wilk Test Statistic](https://en.wikipedia.org/wiki/Shapiro%E2%80%93Wilk_test)            | Tests normality of residuals (how Gaussian the errors are).                       | Values close to **1** = residuals look normal. Low values with small p-value indicate non-normality. | No |

# %% [markdown]
# ### Loading the table of evaluation metrics
# And here's the table of the evaluation metrics on the first five features in our test set:

# %%
model.saveplots=False

# model.predict(train)
# model.predict(test)

# Either we can load it from the test NormData object (if it still exists in memory)
table = test.get_statistics_df().round(3)
display(table)
del table

# Or we can load it from its save location
table = pd.read_csv(
    "../out/models/main_workflow_model_HBR/results/statistics_test.csv",
    index_col="statistic",
).T.round(3)
table
# Out:
# statistic                     EXPV   MACE   MAPE   MSLL    NLL     R2   RMSE  \
# response_vars
# lh_G_and_S_frontomargin      0.236  0.016  0.058 -0.118  1.301  0.236  0.167
# lh_G_and_S_occipital_inf     0.066  0.021  0.059  0.002  1.511  0.064  0.181
# lh_G_and_S_paracentral       0.323  0.012  0.055 -0.159  1.222  0.323  0.155
# lh_G_and_S_subcentral        0.199  0.017  0.047 -0.081  1.380  0.198  0.171
# lh_G_and_S_transv_frontopol  0.240  0.023  0.060 -0.110  1.352  0.232  0.203
#
# statistic                      Rho  Rho_p   SMSE  ShapiroW
# response_vars
# lh_G_and_S_frontomargin      0.427    0.0  0.764     0.986
# lh_G_and_S_occipital_inf     0.231    0.0  0.936     0.985
# lh_G_and_S_paracentral       0.550    0.0  0.677     0.996
# lh_G_and_S_subcentral        0.486    0.0  0.802     0.979
# lh_G_and_S_transv_frontopol  0.455    0.0  0.768     0.991
# statistic                     EXPV   MACE   MAPE   MSLL    NLL     R2   RMSE  \
# lh_G_and_S_frontomargin      0.236  0.016  0.058 -0.118  1.301  0.236  0.167
# lh_G_and_S_occipital_inf     0.066  0.021  0.059  0.002  1.511  0.064  0.181
# lh_G_and_S_paracentral       0.323  0.012  0.055 -0.159  1.222  0.323  0.155
# lh_G_and_S_subcentral        0.199  0.017  0.047 -0.081  1.380  0.198  0.171
# lh_G_and_S_transv_frontopol  0.240  0.023  0.060 -0.110  1.352  0.232  0.203
#
# statistic                      Rho  Rho_p   SMSE  ShapiroW
# lh_G_and_S_frontomargin      0.427    0.0  0.764     0.986
# lh_G_and_S_occipital_inf     0.231    0.0  0.936     0.985
# lh_G_and_S_paracentral       0.550    0.0  0.677     0.996
# lh_G_and_S_subcentral        0.486    0.0  0.802     0.979
# lh_G_and_S_transv_frontopol  0.455    0.0  0.768     0.991

# %% [markdown]
# ### Interpretation of the above table
#
# 1. **EXPV** - Not the most informative measure for NM's, because NM's do more then just predicting the mean. These values are modest, but let's have a look at the plots of the _lh\_G\_and\_S\_occipital\_inf_ later.
# 2. **MACE** - Close to zero for all features, this is good, it means our centiles match the true data distribution very well.
# 3. **MAPE** - Also close to zero. This feature needs to be taken with caution in cases where the actual (the measured value) is very small relative to the variance.
# 4. **MSLL** - All negative, so our model is better than a simple baseline model.
# 5. **NLL** - Not perfect, but still good, very much in line with the expectation for NLL.
# 6. **R2** - Almost exactly mirrors EXPV, no surprises here.
# 7. **RMSE** - The values all look good, but it can not be said with certainty without knowing the scale of the measurement.
# 8. **Rho** - All values indicate that there is a modest correlation between the predicted and actual values. Good, but not perfect.
# 9. **Rho_p** - All are close to zero, meaning that all correlations are strongly significant, even though they are relatively small.
# 10. **SMSE** - These values are all quite large, which indicates that the models do not perform much better than just predicting the mean. Luckily, evaluating NMs is not as simple as just looking at the mean prediction.
# 11. **ShapiroW** - All close to 1, which means that all our deviation scores taken together are approximately normally distributed, which is something we do care about.
#
# From these numbers we can conclude that the model does a good job at fitting to the held-out test data, which means it probably generalizes to other data sources too. We ca
#
# ### Interpretation of the plots
#
# We saw that _lh\_G\_and\_S\_occipital\_inf_ had a relatively low Explained Variance and R2 score. We can inspect the plots to get an idea why that may be.

# %%
import matplotlib.pyplot as plt
import PIL.Image as image
from pathlib import Path

centiles = image.open(
    Path(model.save_dir) / "plots/centiles_lh_G_and_S_occipital_inf_test_harmonized.png"
)
plt.imshow(centiles)
plt.axis("off")
plt.show()

# %% [markdown]
# The centile plot, which plots _lh\_G\_and\_S\_occipital\_inf_ against age, reveals the answer. The centiles are horizontally oriented almost everywhere, which means that there is almost no age-related growth of this cortical feature. If we recall the formula for R2, we can understand why it is almost zero if this is the case.
#
# $$EXPV(Y, \hat{Y}) = 1 - \frac{RSS}{TSS} = 1 - \frac{\sum(y_i - \hat{y}_i)^2}{\sum(y_i - \mu)^2}$$
#
# Where $Y$ is the response variable, $\hat{R}$ is the vector of predictions, and $\mu$ is the mean of $Y$.
#
# The expression equals 0 if the fraction equals 1, which is the case if the above and below terms are equal (and non-zero), and that can only happen if $\hat{y}_i$ is equal to $\mu$ for all $i$. In that case, the predicted mean takes on an identical value ($\mu$) for all observations, i.e. the model predicts a flat mean, which coincides with the actual mean of the data. This describes what can be seen in the plot. The predicted mean that we see is almost flat (for most observed ages, at least), and coincides with the actual mean of the data.
#
# Still, the model fits the actual variance of the data quite well, and can be called a good normative model regardless of the bad R2 score. The low R2 and EXPV scores should not be taken as a reason to reject a normative model, but rather as an indication that the predicted deviation scores do not differ much from the the naive Z-score:
#
# $$z_i = \frac{y_i - E[Y]}{\sqrt{E[Y^2]-E[Y]^2}}$$
#
# ### Plotting
#
# The PCNtoolkit has two important built-in plotting functions:
# 1. `plot_centiles` - produces a centile plot of each feature, either with or without scatter data and conditionals
# 2. `plot_qq` - produces a qq-plot for each feature, where the data can be split by any of the batch_effects
#
# To assess the fit of a normative model, it is important to inspect both. Both can reveal problems with fitting to the target density and may provide clues to improving the model.

# %%
from pcntoolkit import plot_centiles, plot_qq, plot_ridge
# ['AnnArbor_a' 'AnnArbor_b' 'Atlanta' 'Baltimore' 'Bangor' 'Beijing_Zang'
#  'Berlin_Margulies' 'Cambridge_Buckner' 'Cleveland' 'ICBM' 'Leiden_2180'
#  'Leiden_2200' 'Milwaukee_b' 'Munchen' 'NewYork_a' 'NewYork_a_ADHD'
#  'Newark' 'Oulu' 'Oxford' 'PaloAlto' 'Pittsburgh' 'Queensland'
#  'SaintLouis']

model = NormativeModel.load("../out/models/main_workflow_model_HBR")
plot_centiles(
    model,
    centiles=[0.01, 0.5, 0.99],
    scatter_data = train,
)
# Out:
# Sampling: []
# Process: 60478 - 2026-05-05 14:53:15 - Dataset "centile" created.
#     - 150 observations
#     - 150 unique subjects
#     - 1 covariates
#     - 5 response variables
#     - 2 batch effects:
#     	site (1)
# 	sex (1)
#
# Process: 60478 - 2026-05-05 14:53:15 - Computing centiles for 5 response variables.
# Process: 60478 - 2026-05-05 14:53:15 - Computing centiles for lh_G_and_S_transv_frontopol.
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:53:17 - Computing centiles for lh_G_and_S_frontomargin.
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:53:18 - Computing centiles for lh_G_and_S_paracentral.
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:53:20 - Computing centiles for lh_G_and_S_occipital_inf.
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:53:22 - Computing centiles for lh_G_and_S_subcentral.
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:53:24 - Harmonizing data on 5 response variables.
# Process: 60478 - 2026-05-05 14:53:24 - Harmonizing data for lh_G_and_S_transv_frontopol.
# Sampling: []
# Process: 60478 - 2026-05-05 14:53:26 - Harmonizing data for lh_G_and_S_frontomargin.
# Sampling: []
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:53:28 - Harmonizing data for lh_G_and_S_paracentral.
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:53:30 - Harmonizing data for lh_G_and_S_occipital_inf.
# Sampling: []
# Sampling: []
# Process: 60478 - 2026-05-05 14:53:32 - Harmonizing data for lh_G_and_S_subcentral.
# Sampling: []

# %%
import matplotlib as mpl
mpl.rcParams.update({'font.size': 15, 'axes.titlesize': 15, 'axes.labelsize': 15, 'xtick.labelsize': 12, 'ytick.labelsize': 12})

plot_qq(
    test,
    plot_id_line=True,
    )

# %% [markdown]
# From the above plots it is evident that the models fit the data well. The centiles closely mirror the data density and the qq-plots show close to perfect Z-score distribution. For a good discussion of the interpretation of the QQ-plots, see Richard Dinga's 2021 paper, "Normative modeling of neuroimaging data using generalized additive models of location scale and shape".
#
# ### Limitations and caveats
#
# Anyone who uses a HBR model in the PCNtoolkit will discover quickly that these models take a long time to fit. The problem arises because the models have to be quite complex to be useful, but still have to be relatively easy to configure, and also transferrable. The way the PCNtoolkit is set up should give reasonable performance on many different kinds of datasets, but this comes at the cost of high computational demand.
